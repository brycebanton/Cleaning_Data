# %% [markdown]
# # Module 5 Homework - Cleaning Up the MoMA Artwork
#
# In this lab, you will put your Pandas data cleaning skills to the test by cleaning up the MoMA artwork csv file.  Solve each of the following problems using the functions from `dfply`.
#
# For each problem, perform two steps.
#
# 1. Explore the specified column using the techniques from the last lecture.
# 2. Fix all issues found in part 1.
#
# **Note that I will be looking for a literate, easy to follow, set of code and markdown cells.**  Part of your score will be determined by the cleanliness/conciseness of your presentation.
#
# Where possible, solve each problem with one pipe.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from dfply import *
import numpy as np
import re
from more_dfply import extract
from more_dfply import ifelse
from more_dfply import fix_names
# %matplotlib inline

# %%
artwork = pd.read_csv("./data/Artworks.csv")

# %% [markdown]
# ## Problem 1
#
# **Task:** Explore the values of `artist.EndDate` and fix any issues.

# %%
artwork = (artwork >> fix_names)

# %% [markdown]
# Fixing the Names in the artwork data set by removing unwanted characters

# %%
artwork.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
#
#                                    ArtistBio Nationality BeginDate EndDate  \
# 0                      (Austrian, 1841–1918)  (Austrian)    (1841)  (1918)
# 1                        (French, born 1944)    (French)    (1944)     (0)
# 2                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
# 3  (French and Swiss, born Switzerland 1944)          ()    (1944)     (0)
# 4                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
#
#    Gender  Date                                             Medium  ...  \
# 0  (Male)  1896      Ink and cut-and-pasted painted pages on paper  ...
# 1  (Male)  1987                  Paint and colored pencil on print  ...
# 2  (Male)  1903  Graphite, pen, color pencil, ink, and gouache ...  ...
# 3  (Male)  1980  Photographic reproduction with colored synthet...  ...
# 4  (Male)  1903  Graphite, color pencil, ink, and gouache on tr...  ...
#
#                                         ThumbnailURL Circumference_cm  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...              NaN
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...              NaN
# 2  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...              NaN
# 3  http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...              NaN
# 4  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...              NaN
#
#   Depth_cm Diameter_cm Height_cm Length_cm Weight_kg  Width_cm Seat_Height_cm  \
# 0      NaN         NaN   48.6000       NaN       NaN  168.9000            NaN
# 1      NaN         NaN   40.6401       NaN       NaN   29.8451            NaN
# 2      NaN         NaN   34.3000       NaN       NaN   31.8000            NaN
# 3      NaN         NaN   50.8000       NaN       NaN   50.8000            NaN
# 4      NaN         NaN   38.4000       NaN       NaN   19.1000            NaN
#
#   Duration_sec
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# Looking to see if the column names look nice after fixing them. Also exploring the data.

# %%
artwork.EndDate.head(10)
# Out:
# 0    (1918)
# 1       (0)
# 2    (1957)
# 3       (0)
# 4    (1957)
# 5       (0)
# 6       (0)
# 7       (0)
# 8       (0)
# 9       (0)
# Name: EndDate, dtype: object

# %% [markdown]
# Looking at the EndDate column. There needs to be cleaning as the dates a in ()

# %%
artwork = (artwork
>> mutate(EndDate_strip = X.EndDate.str.replace('[()]', ''))
)
artwork.head(5)
# Out:
# /home/vn6415dw/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/dfply/base.py:82: FutureWarning: The default value of regex will change from True to False in a future version.
#   **_context_kwargs(kwargs)(x)),
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
#
#                                    ArtistBio Nationality BeginDate EndDate  \
# 0                      (Austrian, 1841–1918)  (Austrian)    (1841)  (1918)
# 1                        (French, born 1944)    (French)    (1944)     (0)
# 2                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
# 3  (French and Swiss, born Switzerland 1944)          ()    (1944)     (0)
# 4                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
#
#    Gender  Date                                             Medium  ...  \
# 0  (Male)  1896      Ink and cut-and-pasted painted pages on paper  ...
# 1  (Male)  1987                  Paint and colored pencil on print  ...
# 2  (Male)  1903  Graphite, pen, color pencil, ink, and gouache ...  ...
# 3  (Male)  1980  Photographic reproduction with colored synthet...  ...
# 4  (Male)  1903  Graphite, color pencil, ink, and gouache on tr...  ...
#
#   Circumference_cm Depth_cm Diameter_cm Height_cm Length_cm Weight_kg  \
# 0              NaN      NaN         NaN   48.6000       NaN       NaN
# 1              NaN      NaN         NaN   40.6401       NaN       NaN
# 2              NaN      NaN         NaN   34.3000       NaN       NaN
# 3              NaN      NaN         NaN   50.8000       NaN       NaN
# 4              NaN      NaN         NaN   38.4000       NaN       NaN
#
#    Width_cm  Seat_Height_cm Duration_sec EndDate_strip
# 0  168.9000             NaN          NaN          1918
# 1   29.8451             NaN          NaN             0
# 2   31.8000             NaN          NaN          1957
# 3   50.8000             NaN          NaN             0
# 4   19.1000             NaN          NaN          1957
#
# [5 rows x 30 columns]

# %% [markdown]
# Cleaning the EndDate column by stripping the parenthesis out of the names. So (1934) will be 1934.

# %%
artwork.EndDate_strip.unique()
# Out:
# array(['1918', '0', '1957', ..., '0 1943 1966 1992 1975',
#        '0 1943 1966 1975', '0 1934 1933'], dtype=object)

# %% [markdown]
# Looking at the unique values in the EndDate column. It looks like there are multiple entries in the same spot. '0 1934 1933' is a good example

# %%
artwork['EndDate_strip'] = artwork['EndDate_strip'].astype(str)

# %% [markdown]
# Making the EndDate_strip column into type string instead of object

# %%
max(artwork.EndDate_strip,key=len)
# Out:
# '0 1985 1979 1981 1965 1961 1989 1980 2002 1990 1956 2000 1973 1988 1985 0 2003 2013 1995 1971 1975 1994 1992 1981 1974 2002 1961 1943 1984 1997 1965'

# %% [markdown]
# To clean this using minimal code I need to find the length of the biggest row that has the most entries. There appear to be a max of 31 values in one row in EndDate. This should be even throughout cleaning the others like gender and BeginDate

# %%
EndDate_names = ['EndDate_{0}'.format(c) for c in range(31)]
EndDate_names
# Out:
# ['EndDate_0',
#  'EndDate_1',
#  'EndDate_2',
#  'EndDate_3',
#  'EndDate_4',
#  'EndDate_5',
#  'EndDate_6',
#  'EndDate_7',
#  'EndDate_8',
#  'EndDate_9',
#  'EndDate_10',
#  'EndDate_11',
#  'EndDate_12',
#  'EndDate_13',
#  'EndDate_14',
#  'EndDate_15',
#  'EndDate_16',
#  'EndDate_17',
#  'EndDate_18',
#  'EndDate_19',
#  'EndDate_20',
#  'EndDate_21',
#  'EndDate_22',
#  'EndDate_23',
#  'EndDate_24',
#  'EndDate_25',
#  'EndDate_26',
#  'EndDate_27',
#  'EndDate_28',
#  'EndDate_29',
#  'EndDate_30']

# %% [markdown]
# Here I am making an list of names. It is not a dictionary because separate function takes in a list. Example is ['col1']

# %%
(artwork
 >> separate(X.EndDate_strip, EndDate_names,
             remove=False, convert=True,
            extra='drop', fill='right')
>> select(X.EndDate_strip,X.EndDate_0,X.EndDate_1,X.EndDate_2))
# Out:
#        EndDate_strip EndDate_0  EndDate_1  EndDate_2
# 0               1918      1918        NaN        NaN
# 1                  0         0        NaN        NaN
# 2               1957      1957        NaN        NaN
# 3                  0         0        NaN        NaN
# 4               1957      1957        NaN        NaN
# ...              ...       ...        ...        ...
# 138146   0 1934 1933         0     1934.0     1933.0
# 138147          1943      1943        NaN        NaN
# 138148          1943      1943        NaN        NaN
# 138149          1943      1943        NaN        NaN
# 138150          1943      1943        NaN        NaN
#
# [138151 rows x 4 columns]

# %% [markdown]
# I am applying the separate function on the artwork data set. Plugging in the list of names I made before into the correct spot (EndDate_names). Since there are 31 columns being made the first couple get cut off from the viewing. So I selected the first 3 columns which I know has data in it to see if it worked correctly. Row 138146 appears to have worked nicely. The code below is what it looks like when not selecting a couple of columns.

# %%
(artwork
 >> separate(X.EndDate_strip, EndDate_names,
             remove=False, convert=True,
            extra='drop', fill='right'))
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... EndDate_21  \
# 0           Ink and cut-and-pasted painted pages on paper  ...        NaN
# 1                       Paint and colored pencil on print  ...        NaN
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...        NaN
# 3       Photographic reproduction with colored synthet...  ...        NaN
# 4       Graphite, color pencil, ink, and gouache on tr...  ...        NaN
# ...                                                   ...  ...        ...
# 138146                               Gelatin silver print  ...        NaN
# 138147  One from an illustrated book with four line bl...  ...        NaN
# 138148  One from an illustrated book with four line bl...  ...        NaN
# 138149  One from an illustrated book with four line bl...  ...        NaN
# 138150  One from an illustrated book with four line bl...  ...        NaN
#
#        EndDate_22 EndDate_23 EndDate_24 EndDate_25 EndDate_26 EndDate_27  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 138146        NaN        NaN        NaN        NaN        NaN        NaN
# 138147        NaN        NaN        NaN        NaN        NaN        NaN
# 138148        NaN        NaN        NaN        NaN        NaN        NaN
# 138149        NaN        NaN        NaN        NaN        NaN        NaN
# 138150        NaN        NaN        NaN        NaN        NaN        NaN
#
#         EndDate_28 EndDate_29 EndDate_30
# 0              NaN        NaN        NaN
# 1              NaN        NaN        NaN
# 2              NaN        NaN        NaN
# 3              NaN        NaN        NaN
# 4              NaN        NaN        NaN
# ...            ...        ...        ...
# 138146         NaN        NaN        NaN
# 138147         NaN        NaN        NaN
# 138148         NaN        NaN        NaN
# 138149         NaN        NaN        NaN
# 138150         NaN        NaN        NaN
#
# [138151 rows x 61 columns]

# %% [markdown]
# ## Problem 2
#
# **Task:** Fix the issues with `artwork.Gender`

# %%
artwork.Gender.unique()
# Out:
# array(['(Male)', '(Male) (Male)', '(Male) (Female)',
#        '(Male) (Male) (Male)', '() (Female) (Male)', '(Female)',
#        '(Male) (Female) (Male) (Female)', '() (Male) (Male)',
#        '() (Male) (Male) (Female)', '(Male) (Male) (Female) (Female)',
#        '(Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Female) (Female) (Male)',
#        '(Male) () (Male) (Female) (Male) (Male) (Male) (Male) (Female)',
#        '() (Male)', '()', '() (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) () ()', '() (Male) (Male) (Male) (Male) (Male)',
#        '(Female) (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Female) (Male)',
#        '(Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Female) (Male)',
#        '(Male) (Female) (Male)', '(Male) (Male) () ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male)',
#        '(Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male)',
#        '() () (Female) () ()', '() (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) ()', '() (Female)',
#        '(Male) (Male) ()', '() (Male) (Female)', '() ()',
#        '(Female) (Female)', '(Male) ()', '() (Male) (Male) (Male) (Male)',
#        '(Female) ()', '(Male) (Female) ()', nan,
#        '(Male) (Male) (Male) (Male) (Female) ()',
#        '(Male) (Male) () (Male) ()', '() (Female) (Male) (Male)',
#        '(Male) (Male) (Male) (Male)', '(Male) (Male) (Female)',
#        '(Male) (Male) (Female) ()',
#        '(Male) (Male) (Male) (Male) (Male) ()',
#        '() (Female) (Male) (Male) (Female) (Male)',
#        '(Female) (Male) (Male)', '() () ()',
#        '() (Female) (Male) (Male) (Male) (Male)', '() (Male) (male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Female) (Female) (Female) ()',
#        '() (Male) (Male) (Female) (Female) (Male)',
#        '(Male) (Male) (Male) ()', '() (Female) (Female)',
#        '() (Male) (Male) (Male) (Male) (Male) (Female) (Female)',
#        '(Female) (Female) (Male) (Male) (Male) ()',
#        '(Male) (Female) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Female)',
#        '() (Male) (Male) (Male) (Female) (Female) (Male) (Female) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Female) (Male) (Male) (Male)',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) ()',
#        '(Male) (Female) (Male) (Male) ()',
#        '() (Female) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) ()',
#        '(Female) (Male) (Male) (Male) ()',
#        '() (Male) (Female) (Male) (Male) (Female)',
#        '() (Male) (Male) (Female) (Male) (Male) (Male) (Female) (Male)',
#        '(Male) (Male) (Female) (Male) ()',
#        '(Female) (Male) (Male) (Female) ()',
#        '() (Male) (Female) (Male) (Male) () ()', '(Female) (Male) ()',
#        '() (Male) (Male) (Female) (Male)',
#        '() (Female) (Female) (Male) (Female) (Male)',
#        '(Female) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Female) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Female) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Female) (Male) ()',
#        '() (Male) (Male) (Male) (Female)', '(Male) () (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Female) (Male) (Male) (Male) () (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Female) (Male) (Female) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Male) ()',
#        '(Male) (Male) (Male) () (Male) ()',
#        '(Male) (Female) (Female) (Male) (Male) ()',
#        '(Female) (Female) (Male) (Male) (Female) ()',
#        '(Male) () (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Female) (Male) (Male) (Male) (Female) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) ()',
#        '() (Male) () ()',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() () (Male) () (Male) (Male)', '() (Male) (Male) ()',
#        '(Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) ()',
#        '(Female) (Male) () (Male) (Male) (Male) (Male) (Male) ()',
#        '(Female) (Male) (Female)',
#        '(Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Female) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Female) (Male) (Female) (Female) (Female) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) () () (Male) (Male)',
#        '(Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) ()',
#        '() () (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male)',
#        '() (Female) (Female) (Female) (Male) (Male) (Male) (Female) (Female) () (Male) (Male) (Female) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) () (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Female) (Male) () (Male) () () (Male) (Male) (Male) (Female) (Male) () () (Male) () ()',
#        '(Female) (Female) (Male) (Male) ()',
#        '(Male) (Male) () () (Female) (Male)', '() (Male) () () ()',
#        '(Male) (Female) (Male) (Male) (Male)',
#        '(Female) (Male) (Male) (Female) (Female) ()',
#        '(Female) (Female) (Female) (Male) (Male) ()',
#        '(Male) (Male) () (Male) (Male) (Male) (Male)', '() () () (Male)',
#        '(Male) () (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Female) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() () () (Male) () (Female)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Female) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Female) ()',
#        '(Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Male) ()',
#        '(Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) ()',
#        '(Male) (Male) () () (Male)',
#        '(Male) (Male) (Male) (Female) (Male) (Male)',
#        '(Male) (Male) () (Male)', '() (Male) ()',
#        '(Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) () (Male) (Male) ()',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) () (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) () (Male) (Male) (Female)',
#        '(Male) (Male) (Male) (Male) () (Female) (Male) (Male) (Male) (Male)',
#        '() (Female) (Male) ()', '() (Male) (Female) (Female)',
#        '(Male) (Male) (Male) (Male) (Male) (Female) (Female) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) ()',
#        '(Male) (Male) () (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Female)',
#        '(Male) (Male) (Male) (Male) (Female) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male)',
#        '(Male) () (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) () (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '() () () ()', '(Male) (Female) (Male) (Female) ()',
#        '(Male) (Female) (Female) (Male) ()',
#        '(Female) (Male) (Male) (Female) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Female) (Female) (Female) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Female) (Male) (Male)',
#        '() (Male) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '() (Female) (Male) (Male) (Female)',
#        '() (Female) (Male) () (Male)',
#        '(Male) (Male) (Female) (Male) (Male) (Male) ()',
#        '(Female) (Female) (Male) (Female) (Male) (Male) (Male) ()',
#        '(Female) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Female) (Male) ()',
#        '(Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Female)', '(Female) (Female) (Male) ()',
#        '(Male) (Female) (Female)', '(Female) (Female) (Female) (Male)',
#        '(Female) (Female) (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) () (Female) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) () () (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Male)',
#        '() (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Female)',
#        '() (Female) (Male) (Female) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Male)',
#        '() (Female) (Female) (Female)',
#        '() (Female) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) ()',
#        '() (Male) (Female) (Male)', '(Male) () () () (Male) ()',
#        '() (Female) (Male) (Male) (Male) (Female) (Female) (Female)',
#        '(Male) () (Male) () ()', '(Male) (Male) (Male) () ()',
#        '(Male) (Male) () () ()', '() () (Male) (Male) ()',
#        '(Male) (Female) (Male) (Male) () ()',
#        '(Male) (Female) (Male) () ()', '(Male) () (Male) () (Male) ()',
#        '(Male) (Female) (Female) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Female) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Female) ()',
#        '(Male) (Male) (Male) (Female) (Female) (Male) (Male) (Female) (Male) (Male) (Male) ()',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) () (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Female) (Male) (Female) ()',
#        '(Male) (Male) () (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Female) (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) ()',
#        '() (Male) (Female) (Male) (Male) (Male) (Male) () (Male) (Male) (Female) (Male) (Male) (Female) (Male) () (Male) (Female) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Female) (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Female) (Male) (Female) (Female) (Male) (Male) (Female) (Male) (Female) (Female) (Male) (Female) (Male) (Female) (Female) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Male) () (Male) (Female) (Male) (Male) (Female) (Male) (Male)',
#        '() () (Male) (Male) (Male) () () ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) ()',
#        '(Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Female) (Female) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Female) (Male) (Male) (Male)',
#        '(Male) (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Female) (Female) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female)',
#        '() (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) () (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) ()',
#        '() () () () () () () (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Female) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Female) (Male) (Male) ()',
#        '(Male) () (Male) (Male) (Female) (Male) (Male) () (Male) (Male) () ()',
#        '(Male) (Male) (Female) (Male) (Male) ()',
#        '(Male) (Male) (Male) () (Female) ()',
#        '(Male) () (Female) (Male) () ()',
#        '() (Male) (Male) () (Female) (Male)',
#        '(Male) () (Male) (Male) (Female) ()',
#        '() (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) () (Male) (Male) (Male) (Female)',
#        '() (Male) (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Female)',
#        '(Male) () () ()', '() (Male) (Female) ()',
#        '(Male) () () () () () (Male) () () ()',
#        '(Female) (Female) (Female) ()',
#        '(Male) (Male) (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Male) () (Male) (Male) (Male) ()',
#        '(Male) (Female) () ()', '() () () () () ()',
#        '(Female) (Male) () (Male) ()', '(Male) (Male) (Female) (Male)',
#        '() () (Female) (Male) (Male) ()', '() () () () ()',
#        '() () (Male) (Male)', '(Male) (Female) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Female) (Male) ()',
#        '(Male) (Female) (Male) (Female) (Male) ()',
#        '(Female) (Female) (Male) (Female) ()',
#        '() (Male) (Male) (Male) () (Female) () () ()',
#        '(Female) () (Male) (Male) (Male) (Male) (Male) () (Male) (Male) (Male) (Female)',
#        '() (Male) (Female) (Male) (Female) (Male)',
#        '(Female) (Male) (Female) (Male) ()',
#        '() (Male) (Female) (Male) (Male) (Male) (Female) (Female) (Female) (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Female) () (Female) (Male)', '(Male) (Female) () (Male)',
#        '(Female) () ()',
#        '() (Female) (Male) (Male) (Male) (Male) () (Male) () ()',
#        '() (Male) (Female) (Female) () (Male) (Male) (Male) () () () () () () () () ()',
#        '(Female) (Male) (Male) (Female) () ()',
#        '() () () () (Male) () ()', '(Female) () (Male)',
#        '(Male) (Male) (Female) (Male) () ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female)',
#        '(Male) () (Male)', '(Female) (Male) (Female) (Male) (Male) () ()',
#        '(Non-Binary)', '() (Female) (Female) (Male)',
#        '() (Male) (Female) (Female) (Male)',
#        '(Male) (Female) (Male) (Male)', '(male)',
#        '() (Male) (Female) () (Male) (Male)',
#        '() (Male) (Non-Binary) (Female) (Female) (Female)',
#        '(Male) (Male) (Male) (Female) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) () () (Male) (Male) (Female) (Male) (Male) (Male) () () (Male) (Male) (Male) (Male) (Female)',
#        '(Male) (Male) (Male) (Male) (Male) () () (Male) (Male) (Female) (Male) (Male) (Male) () () (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) () (Male)',
#        '(Male) (Male) (Male) (Female) (Male) (Male) (Male)',
#        '(Male) (Male) (Female) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Female)',
#        '() (Male) (Male) () (Male) (Female) () (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Female) (Male) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male)',
#        '(Male) () (Male) (Male) (Male) (Male)',
#        '() (Female) (Female) (Female) (Female) (Male)',
#        '() (Male) (Male) () (Male) (Male) (Female) (Male) (Female) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) () (Male) (Male)',
#        '() (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Female) (Male) (Male) (Male)',
#        '(Male) (Male) (Female) (Male) (Male) (Female) () (Male) () (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) () (Male) (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) () () (Male) (Female) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male)',
#        '() (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) () (Male) (Male) (Male) (Male)',
#        '(Male) () (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) () (Male) (Male)',
#        '() (Female) (Female) (Male) (Male)', '(Male) () () (Male) ()',
#        '() (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female) (Female)',
#        '(Male) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '() (Male) () (Male) () (Male) (Male)',
#        '() (Female) (Female) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) (Male) () (Male) (Male) () (Male) () (Male) () (Male) () (Male) (Male) ()',
#        '() (Male) (Male) () (Male) (Male) (Male) () (Male) () () (Male) (Male) ()',
#        '() () (Female) () (Male) (Male) () (Male) (Male) (Female) (Male) (Male) () () () (Male) (Male) () (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '() (Male) (Male) () (Male) (Male) (Male)',
#        '(Female) (Female) (Male) (Female) (Male)',
#        '(Male) (Female) () (Male) ()', '(Male) (Male) () (Female)',
#        '(Male) (Male) (Female) (Male) (Male)',
#        '(Male) (Male) (Male) (Male) (Female) (Male) (Female)',
#        '(Male) () (Male) (Male) (Female) (Male)',
#        '(Male) () () (Male) (Male) (Male) ()',
#        '(Male) (Male) (Female) () (Male) ()',
#        '(Female) () (Male) (Female) (Male) (Female) (Male)',
#        '(Male) () (Male) (Female)', '(Male) () (Male) () (Female)',
#        '(Male) () (Male) (Male) (Male)',
#        '(Male) (Male) (Male) () (Male) (Male)',
#        '(Male) () (Male) (Male) () ()', '() () (Male) (Male) (Male)',
#        '(Male) () (Female) (Male) (Male) (Male) () (Male) (Male) () ()',
#        '() (Male) () () (Male)', '(Male) () () (Male)',
#        '(Male) (Male) (Male) (Female) () (Male)', '(Male) () (Female)',
#        '(Male) (Female) (Female) (Female)',
#        '() (Male) (Male) (Male) (Male) () (Male) (Female) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '(Male) () (Female) (Male)',
#        '() () (Female) (Female) (Female) (Female)',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male)',
#        '(Male) () (Male) () (Male)', '() (Female) (Female) () (Male)',
#        '(Female) (Female) (Female)',
#        '() (Female) (Male) (Male) (Female) (Female) (Male)',
#        '() (Male) (Male) () (Male) (Female) (Female)',
#        '() (Male) (Male) (Female) (Male) (Male) (Female)',
#        '() (Female) (Male) (Female) (Male) (Female) (Male)',
#        '() (Male) (Male) (Male) (Male) () (Male)',
#        '() (Male) (Male) (Male) (Male) (Male) () () (Male) () (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) () (Male)',
#        '() (Male) () (Male) () (Male) () ()',
#        '() (Male) (Female) (Male) (Male) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) () () () () ()',
#        '() () (Male) (Female) (Female) (Male) (Female)',
#        '(Female) (Male) (Male) () (Male) (Male) (Male) () (Female) (Male) () () (Female) (Male) (Male)',
#        '() (Male) () () (Female) (Male)',
#        '(Female) (Male) (Female) (Male) (Male) (Male) (Male)',
#        '(Female) (Male) (Female) (Male) (Male) (Male)',
#        '(Female) (Male) (Male) (Female) (Male) (Male)',
#        '() (Female) (Male) (Male) (Male) (Male) ()',
#        '(Female) (Male) (Female) (Male) (Male)', '(Male) () () () (Male)',
#        '() () (Female) () () (Male) (Female) () (Male) () (Male) ()',
#        '() () (Male) (Male) (Male) (Male)', '() () (Male) ()',
#        '() () (Male) (Male) (Male) (Male) () () () () () ()',
#        '(Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) () (Female) (Male) (Male) (Male) (Male) (Male) (Male) ()',
#        '(Female) (Male) () ()', '(Female) (Male) (Male) (Male)',
#        '(Male) () (Male) ()',
#        '(Male) (Male) (Male) (Male) (Male) () (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) (Male) (Female) ()',
#        '(Female) () (Male) (Male) (Male) (Male)', '(Female) () (Male) ()',
#        '() () () () () () () () () () () () () () () (Male)',
#        '() () () () () () () (Male)',
#        '() () () () () () () () () () () () () (Male)',
#        '() () () () () () () () () (Male)',
#        '() () () () () () () () () () () () () () () () () () () () () (Male)',
#        '(Male) () (Male) () (Male) () () ()', '() () () () () () (Male)',
#        '() (Male) () () (Male) () (Male) () (Male) (Female) () (Male) () (Female) () () (Female) (Male)',
#        '() (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) () (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Female)',
#        '() (Male) (Male) (Female) (Female)',
#        '(Male) (Male) () () (Male) () () ()',
#        '() (Female) (Male) (Male) (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Female)',
#        '(Male) () (Male) (Male) (Male) (Male) ()',
#        '(Male) (Male) (Male) (Male) () () ()',
#        '() (Male) (Male) (Male) (Male) (Female) (Male) (Female) (Male)',
#        '(Female) (Male) (Male) (Male) (Male) (Female) () (Male)',
#        '() (Male) () (Male) () (Male) (Female) (Male) (Male) (Male)',
#        '(Male) (male)',
#        '() (Male) (Female) (Female) (Female) (Male) (Female) () (Male) (Male) (Female)',
#        '(Female) (Female) ()', '() (Female) (Male) (Female)',
#        '() (Female) () ()', '(Female) () () ()',
#        '(Male) (Male) (Male) (Male) (Male) (Female) (Female) (Male) (Male) (Male) (Male)',
#        '(Male) (Female) (Male) (Male) (Male) (Female) (Male)',
#        '() (Male) (Male) () (Male) (Male) (Male) (Female)',
#        '() (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female) (Male)',
#        '() (Male) (Male) (Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Female)',
#        '() (Female) (Male) (Male) (Female) (Male) (Male) (Female) (Male) (Male) (Male)',
#        '() (Male) (Male) (Male) () (Male) (Male) (Male) (Male)',
#        '() (Female) (Male) (Female) (Female) (Female) (Male) (Male) (Male) (Female)',
#        '() (Female) (Male) (Female) (Male) (Male) (Female) (Male)',
#        '(Male) () () () ()',
#        '() (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male)',
#        '(Male) (Male) () (Male) (Male) (Male)',
#        '() (Female) (Female) (Male) (Female) (Female) (Female) (Female) (Male) (Male) (Female) (Male)',
#        '(female)', '() (Male) (Male) (Female) (Female) (Female) (Female)',
#        '(Non-binary)'], dtype=object)

# %% [markdown]
# Checking the unique varaibles for the gender column. This is a complete mess as their are alot of unique variables in the same row. Their should be 31 as discussed for the EndDate.

# %%
artwork = (artwork
>> mutate(Gender_Stripped = X.Gender.str.replace('[()]', ''))
)
# Out:
# /home/vn6415dw/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/dfply/base.py:82: FutureWarning: The default value of regex will change from True to False in a future version.
#   **_context_kwargs(kwargs)(x)),

# %% [markdown]
# Removing the () around the values in the Gender column. (Male) -> Male, (Male) (Male) -> Male Male

# %%
artwork['Gender_Stripped'] = artwork['Gender_Stripped'].astype(str)

# %% [markdown]
# Making the dtype of the Gender_Stripped column (clean) into a str for separate function use

# %%
Gender_names = ['Gender_{0}'.format(c) for c in range(31)]
Gender_names
# Out:
# ['Gender_0',
#  'Gender_1',
#  'Gender_2',
#  'Gender_3',
#  'Gender_4',
#  'Gender_5',
#  'Gender_6',
#  'Gender_7',
#  'Gender_8',
#  'Gender_9',
#  'Gender_10',
#  'Gender_11',
#  'Gender_12',
#  'Gender_13',
#  'Gender_14',
#  'Gender_15',
#  'Gender_16',
#  'Gender_17',
#  'Gender_18',
#  'Gender_19',
#  'Gender_20',
#  'Gender_21',
#  'Gender_22',
#  'Gender_23',
#  'Gender_24',
#  'Gender_25',
#  'Gender_26',
#  'Gender_27',
#  'Gender_28',
#  'Gender_29',
#  'Gender_30']

# %% [markdown]
# Making a list of 31 names for gender

# %%
(artwork
 >> separate(X.Gender_Stripped, Gender_names,
             remove=False, convert=True,
            extra='drop', fill='right')
>> select(X.Gender_Stripped,X.Gender_1,X.Gender_2,X.Gender_3))
# Out:
#        Gender_Stripped Gender_1 Gender_2 Gender_3
# 0                 Male      NaN      NaN      NaN
# 1                 Male      NaN      NaN      NaN
# 2                 Male      NaN      NaN      NaN
# 3                 Male      NaN      NaN      NaN
# 4                 Male      NaN      NaN      NaN
# ...                ...      ...      ...      ...
# 138146       Male Male     Male     Male      NaN
# 138147          Female      NaN      NaN      NaN
# 138148          Female      NaN      NaN      NaN
# 138149          Female      NaN      NaN      NaN
# 138150          Female      NaN      NaN      NaN
#
# [138151 rows x 4 columns]

# %% [markdown]
# I am applying the separate function on the artwork data set. Plugging in the list of gender names I made before into the correct spot (Gender_names). Since there are 31 columns being made the first couple get cut off from the viewing. So I selected the first 3 columns which I know has data in it to see if it worked correctly. Row 138146 appears to have worked since it contianed 'Male Male' in the same spot. The code below is what it looks like when not selecting a couple of columns.

# %%
artwork = (artwork
 >> separate(X.Gender_Stripped, Gender_names,
             remove=False, convert=True,
            extra='drop', fill='right'))

# %% [markdown]
# ## Problem 3
#
# **Task:** Fix the issues with `artwork.BeginDate` and `artwork.EndDate`.  Note that you will want to convert to `.astype('int64')` at the end of the expression.

# %%
artwork = (artwork
>> mutate(BeginDate_strip = X.BeginDate.str.replace('[()]', ''))
)
artwork
# Out:
# /home/vn6415dw/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/dfply/base.py:82: FutureWarning: The default value of regex will change from True to False in a future version.
#   **_context_kwargs(kwargs)(x)),
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... Gender_22  \
# 0           Ink and cut-and-pasted painted pages on paper  ...       NaN
# 1                       Paint and colored pencil on print  ...       NaN
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...       NaN
# 3       Photographic reproduction with colored synthet...  ...       NaN
# 4       Graphite, color pencil, ink, and gouache on tr...  ...       NaN
# ...                                                   ...  ...       ...
# 138146                               Gelatin silver print  ...       NaN
# 138147  One from an illustrated book with four line bl...  ...       NaN
# 138148  One from an illustrated book with four line bl...  ...       NaN
# 138149  One from an illustrated book with four line bl...  ...       NaN
# 138150  One from an illustrated book with four line bl...  ...       NaN
#
#        Gender_23 Gender_24 Gender_25 Gender_26 Gender_27 Gender_28  Gender_29  \
# 0            NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 1            NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 2            NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 3            NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 4            NaN       NaN       NaN       NaN       NaN       NaN        NaN
# ...          ...       ...       ...       ...       ...       ...        ...
# 138146       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 138147       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 138148       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 138149       NaN       NaN       NaN       NaN       NaN       NaN        NaN
# 138150       NaN       NaN       NaN       NaN       NaN       NaN        NaN
#
#        Gender_30 BeginDate_strip
# 0            NaN            1841
# 1            NaN            1944
# 2            NaN            1876
# 3            NaN            1944
# 4            NaN            1876
# ...          ...             ...
# 138146       NaN     0 1861 1860
# 138147       NaN            1889
# 138148       NaN            1889
# 138149       NaN            1889
# 138150       NaN            1889
#
# [138151 rows x 63 columns]

# %%
artwork = (artwork
>> mutate(EndDate_strip = X.EndDate.str.replace('[()]', ''))
)
# Out:
# /home/vn6415dw/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/dfply/base.py:82: FutureWarning: The default value of regex will change from True to False in a future version.
#   **_context_kwargs(kwargs)(x)),

# %% [markdown]
# Cleaning the BeginDate column by removing the () around the numbers

# %%
artwork['BeginDate_strip'] = artwork['BeginDate_strip'].astype(str)
artwork['EndDate_strip'] = artwork['EndDate_strip'].astype(str)

# %% [markdown]
# I already cleaned EndDate but I am putting the code down here as well. Here I am making BeginDate and EndDate dtypes to strings

# %%
BeginDate_names = ['BeginDate_{0}'.format(c) for c in range(31)]
EndDate_names = ['EndDate_{0}'.format(c) for c in range(31)]

# %% [markdown]
# Making the 31 names for BeginDate and EndDate

# %%
artwork = (artwork
 >>separate(X.BeginDate_strip, BeginDate_names,remove=False, convert=True,extra='drop', fill='right')
 >>separate(X.EndDate_strip, EndDate_names,remove=False, convert=True,extra='drop', fill='right'))

# %%
(artwork
 >> select(X.BeginDate_strip,X.BeginDate_0,X.BeginDate_1,X.BeginDate_2,
           X.EndDate_strip,X.EndDate_0,X.EndDate_1,X.EndDate_2))
# Out:
#        BeginDate_strip BeginDate_0  BeginDate_1  BeginDate_2 EndDate_strip  \
# 0                 1841        1841          NaN          NaN          1918
# 1                 1944        1944          NaN          NaN             0
# 2                 1876        1876          NaN          NaN          1957
# 3                 1944        1944          NaN          NaN             0
# 4                 1876        1876          NaN          NaN          1957
# ...                ...         ...          ...          ...           ...
# 138146     0 1861 1860           0       1861.0       1860.0   0 1934 1933
# 138147            1889        1889          NaN          NaN          1943
# 138148            1889        1889          NaN          NaN          1943
# 138149            1889        1889          NaN          NaN          1943
# 138150            1889        1889          NaN          NaN          1943
#
#        EndDate_0  EndDate_1  EndDate_2
# 0           1918        NaN        NaN
# 1              0        NaN        NaN
# 2           1957        NaN        NaN
# 3              0        NaN        NaN
# 4           1957        NaN        NaN
# ...          ...        ...        ...
# 138146         0     1934.0     1933.0
# 138147      1943        NaN        NaN
# 138148      1943        NaN        NaN
# 138149      1943        NaN        NaN
# 138150      1943        NaN        NaN
#
# [138151 rows x 8 columns]

# %% [markdown]
# Applying the two separate functions for both BeginDate and EndDate. I saved in into artwork_dates so I can do artwork_dates.columns to see if it applied correctly which is seen below.

# %%
list(artwork.columns)
# Out:
# ['Title',
#  'Artist',
#  'ConstituentID',
#  'ArtistBio',
#  'Nationality',
#  'BeginDate',
#  'EndDate',
#  'Gender',
#  'Date',
#  'Medium',
#  'Dimensions',
#  'CreditLine',
#  'AccessionNumber',
#  'Classification',
#  'Department',
#  'DateAcquired',
#  'Cataloged',
#  'ObjectID',
#  'URL',
#  'ThumbnailURL',
#  'Circumference_cm',
#  'Depth_cm',
#  'Diameter_cm',
#  'Height_cm',
#  'Length_cm',
#  'Weight_kg',
#  'Width_cm',
#  'Seat_Height_cm',
#  'Duration_sec',
#  'EndDate_strip',
#  'Gender_Stripped',
#  'Gender_0',
#  'Gender_1',
#  'Gender_2',
#  'Gender_3',
#  'Gender_4',
#  'Gender_5',
#  'Gender_6',
#  'Gender_7',
#  'Gender_8',
#  'Gender_9',
#  'Gender_10',
#  'Gender_11',
#  'Gender_12',
#  'Gender_13',
#  'Gender_14',
#  'Gender_15',
#  'Gender_16',
#  'Gender_17',
#  'Gender_18',
#  'Gender_19',
#  'Gender_20',
#  'Gender_21',
#  'Gender_22',
#  'Gender_23',
#  'Gender_24',
#  'Gender_25',
#  'Gender_26',
#  'Gender_27',
#  'Gender_28',
#  'Gender_29',
#  'Gender_30',
#  'BeginDate_strip',
#  'BeginDate_0',
#  'BeginDate_1',
#  'BeginDate_2',
#  'BeginDate_3',
#  'BeginDate_4',
#  'BeginDate_5',
#  'BeginDate_6',
#  'BeginDate_7',
#  'BeginDate_8',
#  'BeginDate_9',
#  'BeginDate_10',
#  'BeginDate_11',
#  'BeginDate_12',
#  'BeginDate_13',
#  'BeginDate_14',
#  'BeginDate_15',
#  'BeginDate_16',
#  'BeginDate_17',
#  'BeginDate_18',
#  'BeginDate_19',
#  'BeginDate_20',
#  'BeginDate_21',
#  'BeginDate_22',
#  'BeginDate_23',
#  'BeginDate_24',
#  'BeginDate_25',
#  'BeginDate_26',
#  'BeginDate_27',
#  'BeginDate_28',
#  'BeginDate_29',
#  'BeginDate_30',
#  'EndDate_0',
#  'EndDate_1',
#  'EndDate_2',
#  'EndDate_3',
#  'EndDate_4',
#  'EndDate_5',
#  'EndDate_6',
#  'EndDate_7',
#  'EndDate_8',
#  'EndDate_9',
#  'EndDate_10',
#  'EndDate_11',
#  'EndDate_12',
#  'EndDate_13',
#  'EndDate_14',
#  'EndDate_15',
#  'EndDate_16',
#  'EndDate_17',
#  'EndDate_18',
#  'EndDate_19',
#  'EndDate_20',
#  'EndDate_21',
#  'EndDate_22',
#  'EndDate_23',
#  'EndDate_24',
#  'EndDate_25',
#  'EndDate_26',
#  'EndDate_27',
#  'EndDate_28',
#  'EndDate_29',
#  'EndDate_30']

# %% [markdown]
# Here I am making sure the columns applied correctly. I am selecting the orginal clean column and this the first three EndDate and BeginDates. Everything seemed to work

# %% [markdown]
# ## Problem 4
#
# **Task:** Use `value_counts` to identify some issues with `artwork.Artist` and `artwork.Nationality`.  Discuss some strategies to solve these issues.  Do your best to clean these columns up.

# %%
artwork = (artwork
>>mutate(ArtistStrip = X.Artist.str.replace(' ','')))
artwork
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... EndDate_22  \
# 0           Ink and cut-and-pasted painted pages on paper  ...        NaN
# 1                       Paint and colored pencil on print  ...        NaN
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...        NaN
# 3       Photographic reproduction with colored synthet...  ...        NaN
# 4       Graphite, color pencil, ink, and gouache on tr...  ...        NaN
# ...                                                   ...  ...        ...
# 138146                               Gelatin silver print  ...        NaN
# 138147  One from an illustrated book with four line bl...  ...        NaN
# 138148  One from an illustrated book with four line bl...  ...        NaN
# 138149  One from an illustrated book with four line bl...  ...        NaN
# 138150  One from an illustrated book with four line bl...  ...        NaN
#
#        EndDate_23 EndDate_24 EndDate_25 EndDate_26 EndDate_27 EndDate_28  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 138146        NaN        NaN        NaN        NaN        NaN        NaN
# 138147        NaN        NaN        NaN        NaN        NaN        NaN
# 138148        NaN        NaN        NaN        NaN        NaN        NaN
# 138149        NaN        NaN        NaN        NaN        NaN        NaN
# 138150        NaN        NaN        NaN        NaN        NaN        NaN
#
#         EndDate_29 EndDate_30  \
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 138146         NaN        NaN
# 138147         NaN        NaN
# 138148         NaN        NaN
# 138149         NaN        NaN
# 138150         NaN        NaN
#
#                                               ArtistStrip
# 0                                              OttoWagner
# 1                                  ChristiandePortzamparc
# 2                                               EmilHoppe
# 3                                          BernardTschumi
# 4                                               EmilHoppe
# ...                                                   ...
# 138146  ChesnuttBrothersStudio,AndrewChesnutt,LewisChe...
# 138147                                  SophieTaeuber-Arp
# 138148                                  SophieTaeuber-Arp
# 138149                                  SophieTaeuber-Arp
# 138150                                  SophieTaeuber-Arp
#
# [138151 rows x 126 columns]

# %% [markdown]
# Here I am taking out the spaces in the Artist names which will help me later on

# %%
artwork = (artwork
>>mutate(ArtistStrip = X.ArtistStrip.str.replace('-','')))
artwork
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... EndDate_22  \
# 0           Ink and cut-and-pasted painted pages on paper  ...        NaN
# 1                       Paint and colored pencil on print  ...        NaN
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...        NaN
# 3       Photographic reproduction with colored synthet...  ...        NaN
# 4       Graphite, color pencil, ink, and gouache on tr...  ...        NaN
# ...                                                   ...  ...        ...
# 138146                               Gelatin silver print  ...        NaN
# 138147  One from an illustrated book with four line bl...  ...        NaN
# 138148  One from an illustrated book with four line bl...  ...        NaN
# 138149  One from an illustrated book with four line bl...  ...        NaN
# 138150  One from an illustrated book with four line bl...  ...        NaN
#
#        EndDate_23 EndDate_24 EndDate_25 EndDate_26 EndDate_27 EndDate_28  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 138146        NaN        NaN        NaN        NaN        NaN        NaN
# 138147        NaN        NaN        NaN        NaN        NaN        NaN
# 138148        NaN        NaN        NaN        NaN        NaN        NaN
# 138149        NaN        NaN        NaN        NaN        NaN        NaN
# 138150        NaN        NaN        NaN        NaN        NaN        NaN
#
#         EndDate_29 EndDate_30  \
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 138146         NaN        NaN
# 138147         NaN        NaN
# 138148         NaN        NaN
# 138149         NaN        NaN
# 138150         NaN        NaN
#
#                                               ArtistStrip
# 0                                              OttoWagner
# 1                                  ChristiandePortzamparc
# 2                                               EmilHoppe
# 3                                          BernardTschumi
# 4                                               EmilHoppe
# ...                                                   ...
# 138146  ChesnuttBrothersStudio,AndrewChesnutt,LewisChe...
# 138147                                   SophieTaeuberArp
# 138148                                   SophieTaeuberArp
# 138149                                   SophieTaeuberArp
# 138150                                   SophieTaeuberArp
#
# [138151 rows x 126 columns]

# %% [markdown]
# Replacing the '-' with nothing for the names that have it

# %%
 artwork = (artwork
>>mutate(ArtistStrip = X.ArtistStrip.str.replace(',',' ')))
artwork
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... EndDate_22  \
# 0           Ink and cut-and-pasted painted pages on paper  ...        NaN
# 1                       Paint and colored pencil on print  ...        NaN
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...        NaN
# 3       Photographic reproduction with colored synthet...  ...        NaN
# 4       Graphite, color pencil, ink, and gouache on tr...  ...        NaN
# ...                                                   ...  ...        ...
# 138146                               Gelatin silver print  ...        NaN
# 138147  One from an illustrated book with four line bl...  ...        NaN
# 138148  One from an illustrated book with four line bl...  ...        NaN
# 138149  One from an illustrated book with four line bl...  ...        NaN
# 138150  One from an illustrated book with four line bl...  ...        NaN
#
#        EndDate_23 EndDate_24 EndDate_25 EndDate_26 EndDate_27 EndDate_28  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 138146        NaN        NaN        NaN        NaN        NaN        NaN
# 138147        NaN        NaN        NaN        NaN        NaN        NaN
# 138148        NaN        NaN        NaN        NaN        NaN        NaN
# 138149        NaN        NaN        NaN        NaN        NaN        NaN
# 138150        NaN        NaN        NaN        NaN        NaN        NaN
#
#         EndDate_29 EndDate_30  \
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 138146         NaN        NaN
# 138147         NaN        NaN
# 138148         NaN        NaN
# 138149         NaN        NaN
# 138150         NaN        NaN
#
#                                               ArtistStrip
# 0                                              OttoWagner
# 1                                  ChristiandePortzamparc
# 2                                               EmilHoppe
# 3                                          BernardTschumi
# 4                                               EmilHoppe
# ...                                                   ...
# 138146  ChesnuttBrothersStudio AndrewChesnutt LewisChe...
# 138147                                   SophieTaeuberArp
# 138148                                   SophieTaeuberArp
# 138149                                   SophieTaeuberArp
# 138150                                   SophieTaeuberArp
#
# [138151 rows x 126 columns]

# %% [markdown]
# Replacing the columns that have multiple names which contain commas with a space. This will help split the names later.

# %%
artwork = (artwork
>>mutate(ArtistStrip = X.ArtistStrip.str.replace('ChristiandePortzamparc','ChristianDePortzamparc'))
>>mutate(ArtistStrip = X.ArtistStrip.str.replace('Unknownphotographer','UnkownPhotographer'))
>>mutate(ArtistStrip = X.ArtistStrip.str.replace('LudwigMiesvanderRohe ','LudwigMiesVanDerRohe '))
          )
artwork
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... EndDate_22  \
# 0           Ink and cut-and-pasted painted pages on paper  ...        NaN
# 1                       Paint and colored pencil on print  ...        NaN
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...        NaN
# 3       Photographic reproduction with colored synthet...  ...        NaN
# 4       Graphite, color pencil, ink, and gouache on tr...  ...        NaN
# ...                                                   ...  ...        ...
# 138146                               Gelatin silver print  ...        NaN
# 138147  One from an illustrated book with four line bl...  ...        NaN
# 138148  One from an illustrated book with four line bl...  ...        NaN
# 138149  One from an illustrated book with four line bl...  ...        NaN
# 138150  One from an illustrated book with four line bl...  ...        NaN
#
#        EndDate_23 EndDate_24 EndDate_25 EndDate_26 EndDate_27 EndDate_28  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 138146        NaN        NaN        NaN        NaN        NaN        NaN
# 138147        NaN        NaN        NaN        NaN        NaN        NaN
# 138148        NaN        NaN        NaN        NaN        NaN        NaN
# 138149        NaN        NaN        NaN        NaN        NaN        NaN
# 138150        NaN        NaN        NaN        NaN        NaN        NaN
#
#         EndDate_29 EndDate_30  \
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 138146         NaN        NaN
# 138147         NaN        NaN
# 138148         NaN        NaN
# 138149         NaN        NaN
# 138150         NaN        NaN
#
#                                               ArtistStrip
# 0                                              OttoWagner
# 1                                  ChristianDePortzamparc
# 2                                               EmilHoppe
# 3                                          BernardTschumi
# 4                                               EmilHoppe
# ...                                                   ...
# 138146  ChesnuttBrothersStudio AndrewChesnutt LewisChe...
# 138147                                   SophieTaeuberArp
# 138148                                   SophieTaeuberArp
# 138149                                   SophieTaeuberArp
# 138150                                   SophieTaeuberArp
#
# [138151 rows x 126 columns]

# %% [markdown]
# I am fixing the names that could cause issues. The plan is to space the names back out using regex which will split when it sees a lowercase and uppercase letter. So i Had to fix these names so it will follow pattern

# %%
list(artwork.ArtistStrip.unique())
# Out:
# ['OttoWagner',
#  'ChristianDePortzamparc',
#  'EmilHoppe',
#  'BernardTschumi',
#  'LouisI.Kahn',
#  'MarcelKammerer',
#  'OttoSchönthal',
#  'HansPoelzig',
#  'RaimundAbraham',
#  'PeterEisenman RobertCole',
#  'RemKoolhaas MadelonVriesendorp',
#  'RogerC.Ferri',
#  'MichaelGraves',
#  'AldoRossi GianniBraghieri M.Bosshard',
#  'LudwigMiesvanderRohe',
#  'ErikGunnarAsplund',
#  'ErikGunnarAsplund SigurdLewerentz',
#  'PaulNelson FrantzJourdain OscarNitzchke',
#  'PaulNelson OscarNitzchke FrantzJourdain',
#  'StevenHoll',
#  'ErichMendelsohn',
#  'PaoloSoleri',
#  'PaulRudolph',
#  'PeterCook',
#  'Diller+Scofidio ElizabethDiller RicardoScofidio',
#  'ZahaHadid',
#  'FumihikoMaki',
#  'RemKoolhaas ZoeZenghelis EliaZenghelis MadelonVriesendorp',
#  'FrankLloydWright',
#  'MarioBellini',
#  'VenturiandRauch RobertVenturi JohnRauch',
#  'VenturiandRauch RobertVenturi JohnRauch DeniseScottBrown',
#  'Venturi RauchandScottBrown RobertVenturi JohnRauch DeniseScottBrown',
#  'EmilioAmbasz',
#  'TadaoAndo',
#  'ArataIsozaki',
#  'TheovanDoesburg CornelisvanEesteren',
#  'RobertoBurleMarx OscarNiemeyer',
#  'NeilM.Denari',
#  'DavidJacob',
#  'MarioBotta',
#  'R.BuckminsterFuller',
#  'AlessandroMendini',
#  'RobertoBurleMarx',
#  'HerbertBayer',
#  'LeonKrier',
#  'DanielLibeskind',
#  'ThomMayne AndrewZago',
#  'Morphosis SantaMonica CA ThomMayne AndrewZago',
#  'RemKoolhaas EliaZenghelis ZoeZenghelis MadelonVriesendorp',
#  'AldoRossi',
#  'JoelSanders',
#  'MassimoScolari',
#  'KennethSnelson',
#  'ErnestoBrunoLaPadula GiovanniGuerrini MarioRomano',
#  'RichardMeier',
#  'ErnestoBrunoLaPadula GiovanniGuerrini MarioRomano MarioRomano GiovanniGuerrini',
#  'RafaelViñoly',
#  'SantiagoCalatrava',
#  'NormanFoster',
#  'LouisI.Kahn AnnTyng',
#  'RemKoolhaas EliaZenghelis MadelonVriesendorp ZoeZenghelis',
#  'FrederickKiesler',
#  'JasonCrum',
#  'KonradWachsmann',
#  'RicardoBofill',
#  'FrankO.Gehry',
#  'WolfD.Prix HelmutSwiczinsky',
#  'CesarPelli',
#  'ChuckHoberman',
#  'HansHollein',
#  'ScottMarble KarenFairbanks',
#  'RicardoBofill GregoryBaird RogelioJimenez',
#  'YoshitoTakahashi',
#  'TheovanDoesburg',
#  'JamesStirling',
#  'IakovChernikhov',
#  'RobertA.M.Stern',
#  'VenturiandRauch JohnRauch RobertVenturi',
#  'JamesWines AlisonSky MichelleStone EmilioSousa',
#  'HarryC.Wolf',
#  'MehrdadYazdani',
#  'LeCorbusier(CharlesÉdouardJeanneret)',
#  'OscarNitzchke HugoHerdeg',
#  'OscarNitzchke',
#  'EdwardLarrabeeBarnes',
#  'RemKoolhaas GötzKeller WillemJanNeutelings BrigitteKochta MartyKohn LucReuse RonSteiner JeroenThomas GarciellaTorre',
#  'KishoKurokawa',
#  'RichardNeutra',
#  'WielArets',
#  'Herzog&deMeuron Basel JacquesHerzog PierredeMeuron',
#  'SkidmoreOwings&Merrill GordonBunshaft',
#  'ToyoIto',
#  'RemKoolhaas',
#  'DominiquePerraultArchitecture Paris DominiquePerrault',
#  'GaetanoPesce',
#  'JoelSanders Architect JoelSanders',
#  'Taniguchi&Associates YoshioTaniguchi',
#  'BernardTschumiArchitects',
#  'RafaelViñolyArchitects',
#  'TodWilliamsBillieTsienandAssociates',
#  'WalterPichler',
#  'SITE JamesWines',
#  'JohnHejduk',
#  'AndreaBranzi',
#  'PeterEisenman',
#  'YonaFriedman',
#  'RonHerron',
#  'RemKoolhaas EliaZenghelis',
#  'RemKoolhaas ZoeZenghelis',
#  'RodolfoMachado JorgeSilvetti',
#  'MaxPeintner',
#  'CedricPrice',
#  'R.BuckminsterFuller ShojiSadao',
#  'FriedrichSt.Florian',
#  'Superstudio GianPieroFrassinelli AlessandroMagris RobertoMagris AdolfoNatalini CristianoToraldodiFrancia AlessandroPoli',
#  'LaurettaVinciarelli',
#  'AldoRossi GianniBraghieri',
#  'AldoRossi J.daNobrega J.Charters',
#  'EttoreSottsass',
#  'Superstudio CristianoToraldodiFrancia GianPieroFrassinelli AlessandroMagris RobertoMagris AdolfoNatalini',
#  'Superstudio GianPieroFrassinelli AlessandroMagris RobertoMagris AdolfoNatalini CristianoToraldodiFrancia',
#  'Superstudio GianPieroFrassinelli AlessandroMagris RobertoMagris CristianoToraldodiFrancia AdolfoNatalini',
#  'Superstudio GianPieroFrassinelli CristianoToraldodiFrancia AlessandroMagris RobertoMagris AdolfoNatalini',
#  'MathiasUngers G.Geist J.Sawade',
#  'MichaelWebb',
#  'ZoeZenghelis EliaZenghelis',
#  'StevenHollArchitects StevenHoll PeterLynch StephenCassell PierCopat BryanBell FriederikeGrossPietsche ThomasGardner',
#  'StevenHollArchitects StevenHoll MarkJanson JosephFenton SuzannePowadiuk JamesRosen',
#  'RemKoolhaas ArtZaaijer XaveerdeGeijter GeorgesHeinz HeikeLohmann RonSteiner AlexWall ChristopheCornubert RamonKlein YushiUehara',
#  'RemKoolhaas JulienMonfort JeroenThomas YoYamagata JeanneGang ChrisDondorp',
#  'RemKoolhaas GroBonesmo JeroenThomas',
#  'ElizabethDiller RicardoScofidio',
#  'FosterAssociates',
#  'LeCorbusier(CharlesÉdouardJeanneret) PierreJeanneret',
#  'RobertVenturi',
#  'CharlesEames RayEames',
#  'SimonUngers ThomasKinslow',
#  'AlvarAalto',
#  'RichardMeier&Associates Architects',
#  'CharlesGwathmey',
#  'FrankStella EarlChildress RobertKahnArchitects NewYork Nageli&VallebuonaArchitekten Berlin',
#  'GerritRietveld Mrs.TruusSchröderSchräder',
#  'GeorgeHowe WilliamLescaze',
#  'MichaelGraves TimothyWood PeterWaldman PeterCarl RobertWhite ChristopherChimera',
#  'IñakiÁbalos JuanHerreros',
#  'BenvanBerkel',
#  'PhilipJohnson',
#  'EisenmanArchitects NewYork PeterEisenman RichardRosson MarkWamble GregoryMerryweather NazliGononsay',
#  'GwathmeySiegel&AssociatesArchitects CharlesGwathmey RobertSiegel',
#  'Herzog&deMeuron Basel JacquesHerzog PierredeMeuron KarlBlossfeldt',
#  'ToyoIto&Associates Architects',
#  'RemKoolhaas WinyMaas ElizabethAlford XaveerdeGeyter RayMaggiore VinceScirano RonSteiner YushiUehara',
#  'RichardMeier&Partners Architects',
#  'JeanNouvel',
#  'Ortner&Ortner LauridsOrtner ManfredOrtner',
#  'JoelSanders MarcTsurumaki JonathanCrary',
#  'KazuyoSejima&Associates',
#  'NicholasGrimshaw',
#  'TheGroup JuhaKaakko IlkkaLaine KimmoLiimatainen JariTirkkonen',
#  'HeikkinenKomonenArchitects MikkoHeikkinen MarkkuKomonen',
#  'StevenHollArchitects',
#  'RenzoPianoBuildingWorkshop RenzoPiano NoriakiOkabe PeterRice(OveArupandPartners) NikkenSekkeiLtd.',
#  'JoelSanders Architect JoelSanders MarcTsurumaki ErnestGuenzburger SeanKeller DillonKyle CarySiress',
#  'KazuyoSejima&Associates KazuyoSejima',
#  'LudwigMiesVanDerRohe PhilipJohnson Kahn&Jacobs',
#  'MarcelBreuer AlfredRoth EmilRoth',
#  'AsymptoteArchitecture NewYork HaniRashid LiseAnneCouture',
#  'HansCoper',
#  'JamesPrestini',
#  'KajFranck',
#  'JosefHoffmann',
#  'GustaveFalconnier',
#  'UnknownDesigner',
#  'CorningGlassWorks Corning NY',
#  'RonaldHayesPearson',
#  'RodolfoBonetto',
#  'G.ByrnCompany Copenhagen',
#  'RobertOberheim',
#  'CarlAuböck',
#  'L.M.EricssonTelephoneCompany Sweden HugoBlomberg RalphLysell HansGöstaThames',
#  'ReinholdWeiss',
#  'DieterRams GerdAlfredMüller',
#  'JürgenGreubel',
#  'DavidWalterBeck',
#  'MassimoVignelli',
#  'RogerTallon',
#  'DieterRams',
#  'ClausBonderup TorstenThorup',
#  'BrunoMunari',
#  'GinoColombini',
#  'EarlS.Tupper',
#  'KennethBrozen',
#  'GeneHurwitt',
#  'NickRoericht',
#  'GeorgeYgfors',
#  'ThomasW.Winstead',
#  'BertelGardberg',
#  'MagnusStephensen',
#  'SigurdPersson',
#  'RusselWright',
#  'EnzoMari',
#  'JensH.Quistgaard',
#  'PeterRaacke',
#  'MasayukiKurokawa',
#  'DonWallance',
#  'CharlesH.McCrea',
#  'A.L.Pugh S.J.Stein',
#  'WalterZeischegg',
#  'KoenDeWinter',
#  'MichioArai',
#  'ElsaFischerTreyden MargretHildebrand',
#  'RosenthalPorzellanA.G. Germany',
#  'Nason&MorettiStudio',
#  'HenningAndreasen',
#  'AchilleCastiglioni PierGiacomoCastiglioni',
#  'PeterHamburger',
#  'MoikSchiele',
#  'EmilyBelding',
#  'AlexanderGirard',
#  'JacobJensen',
#  'JoeColombo',
#  'S.M.HexterCompany',
#  'GeorgeDodson AkzoNobelGeosyntheticsCompany Asheville NC',
#  'KonwiserInc. NewYork NY',
#  'Nikon(NipponKogakuK.K.) Tokyo',
#  'GiorgioBerretti',
#  'IsamuNoguchi',
#  'MarcoFerreri',
#  'PaulRand',
#  'MargueriteWildenhain',
#  'PeterBehrens',
#  'CarlWalters',
#  'Martin',
#  'NikolaiSuetin',
#  'KazuoKawasaki',
#  'MarianneBrandt',
#  'LeopoldoTartarini',
#  'MakotoKomatsu',
#  'MarcelBreuer',
#  'UgoLaPietra',
#  'RossLittell',
#  'RossLovegrove',
#  'AchilleCastiglioni',
#  'SyntheticIndustries Chattanooga TN',
#  'ChristianDell',
#  'HugoDreyfuss',
#  'MaurizioFiccadenti',
#  'KristianVedel',
#  'SvenMarkelius KaMarkelius',
#  'MassimoVignelli LellaVignelli DavidLaw',
#  'HoechstTreviraGmbH',
#  'JoelRobinson',
#  'TootsZynsky',
#  'ArneJacobsen',
#  'KevinDwyer',
#  'EszterHaraszty',
#  'FlorenceKnoll',
#  'HausRuckerCo GünterZampKelp LauridsOrtner ManfredOrtner KlausPinter',
#  'CarloMoretti',
#  'HugoLeven',
#  'PoulHenningsen',
#  'Vera(VeraNeumann)',
#  'VicoMagistretti',
#  'RenéHerbst',
#  'GebrüderThonet companydesign',
#  'GretlWollner LeoWollner',
#  'BentHedegaardNobert',
#  'CarlJacobs',
#  'JosefFrank',
#  'AngeloTesta',
#  'MontsePadrósiMarqués CarlosRiart',
#  'HarriKoskinen',
#  'PaoloRizzatto',
#  'CharlesEames RayEames UniversityofCaliforniaLosAngelesTeam',
#  'TobiaScarpa AfraScarpa',
#  'LynnAlexander',
#  'StudioTetrarc',
#  'PhilippeStarck',
#  'BrunoMathsson',
#  'OskarStrnad',
#  'SegusoS.R.L. Murano Italy',
#  'MarliEhrman',
#  'PaoloVenini',
#  'HelenaHernmarck',
#  'RichardW.Landis',
#  'MarianneStrengell',
#  'DorothyLiebes',
#  'GianfrancoFrattini LivioCastiglioni',
#  'FaustoMelotti',
#  'BenjaminBaldwin',
#  'TheAluminumCookingUtensilCo. NewYork NY',
#  'PalmeBerthold',
#  'CarlAnderson RossBellah',
#  'PeterSchlumbohm',
#  'YvonneDelattre',
#  'JoaquinPotteryCo. Stockton CA',
#  'HagbardElisBergh',
#  'ManRay(EmmanuelRadnitzky)',
#  'AinoAalto AlvarAalto',
#  'AlbertoSalvati AmbrogioTresoldi',
#  'JackLenorLarsen',
#  'ErichWalterStadler',
#  'BlenkoGlassCo. Inc. Milton WV',
#  'GustavA.Brown',
#  'TheodoreWaddell DanteBandini',
#  'ShoeFormCo. Inc. UtilityBoxDiv. Auburn NY',
#  'MarcoZanuso',
#  'PhilippeStarck JeromeOlivet',
#  'AnniAlbers',
#  'CharlesEames',
#  'CharlesD.Briddell',
#  'P.E.Camerer St.Paul MN',
#  'KayserzinnWorkshop',
#  'GretaVonNessen',
#  'ShuichiObata',
#  'EdwardCondak',
#  'AsaoSakamoto',
#  'CoorsPorcelainCo. Golden CO',
#  'TimoSarpaneva',
#  'ImperialGlassCorp. Bellaire OH',
#  'WilhelmWagenfeld',
#  'HansWegner',
#  'LurelleGuild',
#  'AkihiroKaneko',
#  'Kensington Inc. NewKensington PA',
#  'YoshihiroKimura',
#  'GuntaStölzl',
#  'OsamuMita',
#  'WilliamJ.Russell',
#  'KeijiOtani',
#  'FrankGrahamHolmes',
#  'FlavioPoli',
#  'SakaseAdtechCo. Fukui Japan',
#  nan,
#  'ReikoSudo',
#  'EllenSiegel',
#  'W.ArchibaldWelden',
#  'UraseCo. Ltd. Fukui Japan',
#  'RayEames CharlesEames',
#  'DoraJung',
#  'KoichiYoshimura',
#  'HaroldElberg',
#  'SheilaHicks',
#  'KoichiYoshimura ReikoSudo',
#  'CarloScarpa',
#  'Silverman',
#  'FrancesFelten',
#  'LouisComfortTiffany',
#  'LenoreTawney',
#  'EmileGallé',
#  'LouisComfortTiffany TiffanyStudios NewYork NY',
#  'A.H.Staf',
#  'JohannLoetz',
#  'KarlHagenauer',
#  'HarryHandler',
#  'HarvillCorp. LosAngeles CA',
#  'JackHeaney',
#  'JohnR.Carroll',
#  'EgmontArens TheodoreC.Brookhart',
#  'JonHedu',
#  'HeddaBeese',
#  'AlbinJ.Herek PhilipV.Leivo',
#  'LuigiColani',
#  'G.M.ThurnauerCo. Czechoslovakia',
#  'CharlesEames GregoryAin HarryBertoia NormanBruns RayEames MarionOverby',
#  'YasuhiroKira',
#  'JunichiArai',
#  'Liberty&Co. Ltd. London',
#  'ShiroKuramata',
#  'NECDesign Ltd.',
#  'AntoniGaudí',
#  'MarcelloNizzoli',
#  'EdwardWilliamGodwin',
#  'MichaelRabinowitz',
#  'JosefHoffmann BertholdLöffler',
#  'GöranHongell',
#  'HectorGuimard',
#  'EdRossbach',
#  'WilliamLescaze',
#  'CharlesS.Todd',
#  'LohmannGmbHandCo. Neuwield Germany',
#  'JohnD.Wareham',
#  'RichardRiemerschmid',
#  'SamLucente JohnKaridis RobertP.Tennant RichardSapper IBMCorporation',
#  'LouisMajorelle DaumFrères Nancy France',
#  'SirWilliamLyons MalcolmSayer WilliamM.Heynes',
#  'GerhardMarcks WilhelmWagenfeld',
#  'EijiMiyamoto',
#  'Karlsson&Nilsson Sweden',
#  'WilliamN.Touzani',
#  'HarryJ.Powell',
#  'VernonP.Steele',
#  'RichardSapper',
#  'StephenArmellino',
#  'AfraScarpa TobiaScarpa',
#  'RitvaPuotila',
#  'LesBroersma',
#  'N.V.SchlegelS.A. Gistel Belgium',
#  'GustavStickley',
#  'RobertBrunner',
#  'Lalance&GrosjeanMfg.Co. Woodhaven NY',
#  'JohnR.Morgan',
#  'TonyPaul',
#  'EdwardWormley',
#  'EdE.Langbein',
#  'NormanCherner',
#  'JosefAlbers',
#  'ArthurYoung',
#  'ErnestRace',
#  'TomoyukiSugiyama',
#  'T.H.RobsjohnGibbings',
#  'TorayIndustries Inc. Tokyo',
#  'ErnstLichtblau',
#  'ErikHerløw',
#  'TorayIndustries Inc. Tokyo NittoSeimoCo.Ltd. companydesign',
#  'AndriesDirkCopier',
#  'ReynoldsG.Dennis',
#  'TorayIndustries Inc. Tokyo ToyoTireCordCo.Ltd.',
#  'Unknowndesigner',
#  'AndréGiraud&Brousseau Limoges France',
#  'JonathanW.Strong',
#  'TapioWirkkala',
#  'MetallArbeitWienerWerkstätte',
#  'RaymondLoewyAssociates TheHallicraftersCompanyDesignandResearchTeam',
#  'JohnBehringer',
#  'RodolfoBretzel',
#  'YamazakiVellodoCo.Ltd.',
#  'McDonnellAircraftCorp. St.Louis MO',
#  'KarinSchouAndersen',
#  'ThomasEriksson',
#  'DonMortrude',
#  'HermannGretsch',
#  'ErgonomiDesignGruppen(nowVeryday) MariaBenktzon HåkanBergkvist SvenEricJuhlin',
#  'Alsterfors Sweden',
#  'SoriYanagi',
#  'HansEichenberger',
#  'BenediktRohner',
#  'MorisonS.Cousins MichaelAlanCousins',
#  'AmericanOpticalCorp. Southbridge MA',
#  'RexA.Stevens',
#  'CharlesRennieMackintosh',
#  'BrunoNinaberVanEyben',
#  'Almo NewYork',
#  'GerritRietveld',
#  'CollinsCompany Collinsville CT',
#  'Swift&Anderson Inc. Boston MA',
#  'SylvaniaElectricProducts Inc. NewYork NY',
#  'DavidBush BrianLepine MichaelZimmerman',
#  'CharlottePerriand',
#  'Canon Inc. Japan',
#  'PeterKarpf',
#  'OlgaDeAmaral',
#  'J.&J.Kohn JosefKohn JacobKohn',
#  'KolomanMoser',
#  'RolfKothrade',
#  'Rex(ReginaldC.)Silver',
#  'KyokoKumai',
#  'JurriaanKok JacobusLucasVerhoog',
#  'DavidLewis',
#  'J.P.KayserSohn',
#  'HiroakiKozu',
#  'DaumFrères Nancy France',
#  'Cravell Inc. LongIsland NY',
#  'SteveMcGugan',
#  'AnttiNurmesniemi',
#  'GloriaCaranica',
#  'EkcoProductsCo. Chicago IL',
#  'DeanPollock',
#  'A.L.Hirsch&Co. NewYork NY',
#  'VikingGlassCo. NewMartinsville WV',
#  'HenningWatterston',
#  'KateHarris',
#  'SvendWeihrauch',
#  'LouisvilleTackleCo. Louisville KY',
#  'GerhardBehrend',
#  'DorothyF.Markle HarryC.Markle',
#  'Nybro Sweden',
#  'TheYale&TowneMfg.Co. Stamford CT',
#  'LeslieBeaton',
#  'AmericanSteel&WireCo. Worcester MA',
#  'TelexElectroAcousticDivision',
#  'AluminumCompanyofAmerica Pittsburgh Pennsylvania',
#  'EvaZeisel',
#  'MarianneBrandt HinBredendieck',
#  'MarianneBrandt Bauhaus Dessau',
#  'Bauhaus',
#  'HenryDisston&Sons Inc.',
#  'KarhulaIitala companydesign',
#  'FrancoAlbini',
#  'WarehousePointCo. WarehousePoint CT',
#  'HemcoPlasticsDiv.ofBryantElectricalCo. Bridgeport CT',
#  'EliotNoyesandAssociates',
#  'EeroAarnio',
#  'ConstantinBoym LaureneLeonBoym',
#  'OlafvonBohr',
#  'PeterMüllerMunk',
#  'NickieCampbell WilliamCampbell',
#  'C.HugoPott Solingen Germany',
#  'GertrudNatzler OttoNatzler',
#  'VincentdeRijk',
#  'PoulKjærholm',
#  'AlejandroRuiz',
#  'TrudePetriRaben',
#  'AlicevonPechmann',
#  'JohannesFoersom PeterHiortLoerenzen',
#  'BobHall',
#  'PeterPfisterer',
#  'IntelCorporation SantaClara CA',
#  'PaulMayen',
#  'TheStanleyWorks',
#  'WolfKarnagel',
#  'RainerKüschall',
#  'ThomasLamb',
#  'RussellManoy',
#  'IrvingHarper',
#  'MarioBellini AntonioMacchiCassia GianniPassini',
#  'IngoMaurer',
#  'EeroSaarinen',
#  'HarryV.Cremonese',
#  'M.Schimmel',
#  'EdwardMoulthrop',
#  'WilliamKatavolos DouglasKelley RossLittell AltonKelley',
#  'MichaelWilson',
#  'BillieNewmarch',
#  'Brown&SharpeMfg.Co. Providence RI',
#  'WestBendAluminumCo. Wisconsin',
#  'MichelBufet',
#  'InternationalSilverCo. Meriden CT',
#  'AllanAdler',
#  'ArshileGorky',
#  'IainSinclair',
#  'ChristopherDresser Hukin&Heath Birmingham England',
#  'AntonioCitterio GlenOliverLöw',
#  'HermannFauser',
#  'ChristopherDresser',
#  'BeatriceAlbert',
#  'MercedesFranchini',
#  'AnchorToolCo. USA',
#  'MarianoFortunyYMadrazo',
#  'AdolphLoos',
#  'EugeneDietzgenCompany NewYork NY',
#  'VictorToolCo.',
#  'RomeoMaestri',
#  'DieterRams HansGugelot',
#  'MarcNewson',
#  'HutzlerManufacturingCo.',
#  'WecoliteCo. NewYork NY',
#  'Eimer&Amend NewYork NY',
#  'AllgemeineElektricitätsGesellschaft(A.E.G.) Germany',
#  'JohannesPotente',
#  'MaxBill',
#  'HarveyJ.Finison',
#  'SvenWingquist',
#  'UnknownDesigner Chinese',
#  'AlexJ.Ettl',
#  'AdrianoLagostina MassimoLagostina',
#  'WalterVonNessen',
#  'JeanProuvé',
#  'FederalToolCo. Inc. Springfield MA',
#  'Jernbolaget Eskilstuna Sweden',
#  'JhoonRhee',
#  'ScovillMfg.Co. PlumbersBrassGoodsDiv. Waterbury CT',
#  'FinnJuhl',
#  'PaulSchudel',
#  'LucieRie',
#  'JamesJ.Jacobson',
#  'CharlesO.Perry',
#  'OskarKogoj',
#  'HarryAllen',
#  'GoodellCo. Antrim NH',
#  'OlofBackman',
#  'HansMaierAichen AuthenticsartipresentGmbH Germany',
#  'S.K.F.Industries Inc. Hartford CT',
#  'W.T.Gossard',
#  'CompagniedesCristalleriesdeBaccarat Paris France',
#  'TheL.S.StarrettCo. Athol MA',
#  'BellLaboratories companydesign',
#  'SebastianBergne',
#  'FriedlHolzerKjellberg',
#  'SusanWeitzman',
#  'BioMechanicalComposites CA',
#  'GeorgeNelson',
#  'LucieRie HansCoper',
#  'FrancescaLindh RichardLindh',
#  'SantinaBonini ErnestoSpicciolato',
#  'HarryGitlin',
#  'JosiahWedgwood',
#  'StigLindberg',
#  'ClaudioCesar',
#  'SiegfriedMoeller',
#  'LeniMatthaei',
#  'ThelmaBecherer',
#  'ThomasPatti',
#  'WalterDorwinTeague',
#  'O.J.Kuker Seattle WA',
#  'ScottWilson FritzFoord',
#  'RoyGinstrom',
#  'JohnPemberton',
#  'BMI Germany',
#  'LeCorbusier(CharlesÉdouardJeanneret) PierreJeanneret CharlottePerriand',
#  'LillyE.Hoffman',
#  'RobertoNiederer',
#  'LudwigLittmann',
#  'TheDowChemicalCompany USA',
#  'GiuseppeNason',
#  'StephanRath',
#  'UgoNason',
#  'BobEvans',
#  'EmilioCerri',
#  'GrasoliWerkGebr.Grah Solingen Germany',
#  'NannyStill',
#  'GordonRandallPerry',
#  'WilliamdeVries',
#  'AllenJohnBootroyd',
#  'FiglaResearchCenter',
#  'Lenox Inc. Trenton NJ',
#  'EdwardDurellStone',
#  'DeirdreBurnett',
#  'MichaelLax',
#  'JosephForakis',
#  'TraceAndWarner',
#  'GunnelNyman',
#  "CompagniedeL'EsthétiqueIndustrielle(CEI)RaymondLoewy Paris",
#  'A.F.Gangkofner',
#  'HarryNapper',
#  'EricGoetz',
#  'P.Rigatti Empoli Italy',
#  'VeraLisková',
#  'RichardSüssmuth',
#  'JohnBarnard',
#  'HowattArchery',
#  'MitsuoMaki HosowoTomohiro KikukawaKatsuyoshi M.Katsuyoshi',
#  'RichardSapper SamLucente',
#  'GerdaStrömberg',
#  'ClaireWagnerKosterlitz',
#  'SimonFussell',
#  'IDEO LawrenceLam PaulBradley',
#  'WilliamH.Miller Jr.',
#  'VollrathCo. Sheboygan WI',
#  'MariaBenktzon SvenEricJuhlin',
#  'MatsushitaElectricCorp.',
#  'TakeshiIshiguro',
#  'WalthamScrewCo.',
#  'MosheZabari',
#  'GustavLepschy ErnstLieser KurtSteisslinger',
#  'MitsubishiElectricCorp. Japan',
#  'PerJari JanOhrn',
#  'PolarWareCompany Sheboygan WI',
#  'ArteluceS.A. Milan',
#  'ErnöRubik',
#  'AlexanderBally',
#  'KimJones DougOlson',
#  'JaneDickerman',
#  'AtelierMartine Paris France',
#  'JacquelinePoncelet',
#  'HerbertH.Schultes NorbertSchlagheck',
#  'WardBennett',
#  'SergioAsti',
#  'JeromeSimon',
#  'CasioComputerCo.Ltd.',
#  'AntoniaCampi',
#  'PaulChaleff',
#  'JosefHoffmann OswaldHaerdtl',
#  'FulvioBianconi',
#  'IbiTrierMørch',
#  'LudovicoMares',
#  'OlliAninbaum',
#  'LawrenceLivermoreNationalLaboratory',
#  'CarlHarryStålhane',
#  'BronislawZapolski',
#  'PeterDanko',
#  'AlbertoMeda FrancoRaggi DenisSantachiara',
#  'RossLovegrove StephenPeart KnollInhouseDesignTeam',
#  'TimParsey',
#  'ChristopherConnell',
#  'Wenger Switzerland',
#  'St.RegisPaperCo. PanelyteDiv. NewYork NY',
#  'J.A.Henckels Solingen Germany',
#  'MarkSanders',
#  'MazdaMotorCorporation California',
#  'Vallauris',
#  'MichioHanyu',
#  'AlbertoMeda',
#  'RobertPicault',
#  'TobiaScarpa',
#  'HugoLeven HermannFauser',
#  'JasperMorrison',
#  'TheWatertownManufacturingCo. Watertown CT',
#  'RenzoPiano NoriakiOkabe',
#  'OwensIllinoisGlassCo. Toledo OH',
#  'GeorgeH.Hake',
#  'PaulusvanLeeuwen',
#  'SanfordRedmond',
#  'DonaldGenaro HenryDreyfuss BellTelephoneLaboratories',
#  'BashirZivari',
#  'ScottRiegleman',
#  'OttoPrutscher',
#  'MarcSadler',
#  'JurriaanKok SamuelSchellink',
#  'EmrosTeam',
#  'DavidRowland',
#  'JohnScofield',
#  'PamelaWoodhead',
#  'WaymanR.Spence',
#  'GiorgioGurioli FrancescoScansetti',
#  'WestfieldManufacturingCorp.',
#  'LouisMaslow',
#  'StephenPeart BradfordBissell',
#  'JohnG.Rideout',
#  'SvenPalmqvist',
#  'UmbertoNason',
#  'SaaraHopea',
#  'JeanMichelFolon',
#  'GrossWood EstherWood',
#  'LuigiCacciaDominioni PierGiacomoCastiglioni',
#  'PercyStamp',
#  'CheneyGreef&Co. NewYork NY',
#  'JamesA.Sebastian',
#  'YkiNummi',
#  'WernerBlaser',
#  'BillStewart',
#  'GinoSarfatti',
#  'AntonRüegg',
#  'PhilipJohnson RichardKelly',
#  'RoyRichter FrankHeacox',
#  'KurtVersen',
#  'ThomasV.Paulson',
#  'FratelliGrivel(nowGrivelS.r.l.)',
#  'HarryBertoia',
#  'JoséEchavé',
#  'DeaneRussell',
#  'BenitaKochOtte',
#  'AngeloPatin',
#  'FranklinColvin',
#  'CharlesCurrey',
#  'Hämmerli Ltd. Lenzburg Switzerland',
#  'HowardHead',
#  'HobieAlter',
#  'SlazengersLtd. England',
#  'TorunBülowHübe',
#  'SamuelGragg',
#  'CharlesGwathmey RobertSiegel',
#  'GuglielmoBerchicci',
#  'TorbenHolmback',
#  'MikaelBjörnstjerna',
#  'FordMadoxBrown',
#  'FernandoCampana HumbertoCampana',
#  'ToshiyukiKita',
#  'HenningKoppel',
#  'LouisL.Lepoix',
#  'GodtfredKirkChristiansen',
#  'JacquesSicard',
#  'AllanGittler(AvrahamBarRashi)',
#  'StefanoGiovannoni',
#  'BartvanderLeck',
#  'KonstantinGrcic',
#  'LillyReich LudwigMiesvanderRohe',
#  'InouePleatsCo. Ltd. Fukui Japan',
#  'V.LorenzoPorcelli CarmenBasile',
#  'PorscheDesignGroup',
#  'HendrikVanKeppel TaylorGreen',
#  'RobertVenturi DeniseScottBrown',
#  'SwatchAG Switzerland',
#  'CharlesRobertAshbee',
#  'AleksandrRodchenko',
#  'OlofBackstrom',
#  'NielsSylvesterBendtsen',
#  'ÉdouardWilfredBuquet',
#  'JohnTimothyCurran',
#  'LillyReich',
#  'MakioHasuike',
#  'GiampieroBassi GiovanniBassi',
#  'PaulHaustein',
#  'ArchibaldKnox',
#  'TheCustaniteCorp. Brooklyn NY',
#  'AlessandroBecchi',
#  'JerryMoberg',
#  'RobertWelch',
#  'ClementMeadmore',
#  'RobertS.Gargiuli',
#  'GiancarloMattioli GruppoArchitettiUrbanistiCittàNuova',
#  "JonathanDePas DonatoD'Urbino PaoloLomazzi",
#  'ContinentalCanCo. USA',
#  'C.EmanuelePonzio StudioDA Japan',
#  'SkidmoreOwings&Merrill',
#  'HenriTronquoy',
#  'JavierCarvajal',
#  'NathanGeorgeHorwitt',
#  'MaryWalkerPhillips',
#  'CarloBartoli',
#  'VernerPanton',
#  'RobertDumasHermes WardBennett',
#  'AugustEndell',
#  'DavidGammon',
#  'HansGugelot ReinholdHäcker',
#  'JosephMariaOlbrich',
#  'YrjöKukkapuro',
#  'LouisSullivan',
#  'JohnStram JackStringer CarlNorby',
#  'Desny Paris',
#  'EmilioAmbasz GiancarloPiretti',
#  'LauraAndreson',
#  'OlivierMourgue',
#  'Arabia WärtsiläAb Helsinki Finland',
#  'HansTheoBaumann',
#  'GaeAulenti',
#  'BaldioliEustasio&Figli Omegna Italy',
#  'JayMonroe',
#  'RobertoMenghi',
#  'W.D.Randall',
#  'DonaldR.Knorr',
#  'GunnarCyrén',
#  'VittorioGregotti LodovicoMeneghetti GiottoStoppino',
#  'VanLeerVatenfabriekenN.V. Amstelveen TheNetherlands',
#  'NilsLandberg',
#  'CoDerr',
#  'DavisJ.Pratt',
#  'GerdAlfredMüller',
#  'TakakoSaito',
#  'AageHelbigHansen',
#  'DavidKindersley',
#  'FrankD.Stratton',
#  'MorisonS.Cousins',
#  'GianfrancoFrattini',
#  'Apple Inc. StephenPeart RaymondRiley DavidShen',
#  'W.R.Case&SonsCutleryCo. Bradford PA',
#  'UdoM.Geissler',
#  'StevenT.Kaneko',
#  'KarlKoepping',
#  'RobertJ.King',
#  'M&Co',
#  'Panasonic',
#  'WilfredO.Langille FrederikLjungström',
#  'MariaMartinez PopoviDa',
#  'RobertMichel',
#  'KariVirtanen',
#  'JanMatthias',
#  'MarcoZanuso RichardSapper',
#  'BillMoggridge StephenHobson GlennEdens',
#  'NationalSemiconductorCorporation USA',
#  'BarcaloManufacturingCo. NewYork NY',
#  'DrainDriCo. SanFrancisco CA',
#  'GeorgeOhr',
#  'TheWinstedHardwareManufacturingCo. Winsted CT',
#  'WilfredPezold',
#  'ColinSchuster CraigSchuster',
#  'AchilleCastiglioni PierGiacomoCastiglioni LivioCastiglioni',
#  'UrsulaMorleyPrice',
#  'EmmaGismondiSchweinberger',
#  'UmbertoCatalano GianfrancoMasi',
#  'Pininfarina(Battista"Pinin"Farina)',
#  'GruppoG14 GianfrancoFacchetti UmbertoOrsoni GianniPareschi GiuseppePensotti RobertoUbaldi',
#  'LuigiMassoni',
#  'Dr.JohnMcArthur',
#  'EleanorePeduzziRiva',
#  'V.LorenzoPorcelli PaulD.Miller',
#  'GiancarloPiretti',
#  'DaleR.Caldwell PaulD.Miller',
#  'WilliamLansingPlumbandAssociates',
#  'RobertoSambonet',
#  'VirgilioForchiassin',
#  'StudioOpi',
#  "UncleSam'sUmbrellaShop NewYork NY",
#  'StudioTg',
#  'Olivier',
#  'ArianBrekveld',
#  'AnneliesDeLeede',
#  'FormGmbH Germany',
#  'RodyGraumans',
#  'DouglasScott',
#  'HellaJongerius',
#  'HarveyLittleton',
#  'AinoAalto',
#  'TejoRemy',
#  'IrvingHarper GeorgeNelsonAssociates',
#  'EricRandmark',
#  'JosvanderMeulen',
#  'MarcelWanders',
#  'GiandomenicoBelotti',
#  "Ari'tHart",
#  'JacobJongert',
#  'RuudJanKokke',
#  'MalloryIndustries Inc. Farmington CT',
#  'CentrokappaDesignandCommunication',
#  'DeanL.Fisher',
#  'IsaacI.Cole',
#  'NancyGuayGiesberger',
#  'JamesHamilton',
#  'GöranÅslin',
#  'AlanRandallBest',
#  'MagdalenaAbakanowicz',
#  'AchilleCastiglioni PioManzù',
#  'DieterRams DietrichLubs',
#  'LucienVlerick',
#  'RichardKelly',
#  'HenryClemensvandeVelde',
#  'JanWichers AlexanderBlomberg',
#  'NaokiYoshimoto',
#  'MarcoZotta',
#  'JohnBarnard FerrariS.p.A. Maranello Italy',
#  'DonaldT.Chadwick WilliamStumpf',
#  'frogdesign Sunnydale CA',
#  'PierretteBloch',
#  'Apple Inc. SteveJobs JerryManock',
#  'PeerBücking',
#  'SmartDesign NewYork',
#  'HansOfner',
#  'MarcvandeLoo TimParsey',
#  'DarrellLandrum',
#  'DaniloAroldi CorradoAroldi',
#  'GiulioLazzotti',
#  'GugelotInstitute',
#  'YoshiakiIida',
#  'AssociatedSpringRaymondBarnesGroup Inc. Dallas TX',
#  'TheodorBogler',
#  'WernerAisslinger',
#  'DeanL.Fisher HancockLaverne',
#  'SvenEricJuhlin',
#  'WendellCastle',
#  'DietrichLubs',
#  'CSS/Winfield',
#  'RobertP.Gottlieb',
#  'TomDixon',
#  'Siemens&HalskeA.G. Munich Germany',
#  'AntonioMacchiCassia',
#  'PeterHamburger IngoMaurer',
#  'DavideMercatali PaoloPedrizzetti',
#  'EzioPirali',
#  'GiuseppedeGoetzen',
#  'CesareLeonardi FrancaStagi',
#  'KanekoOrimonoCo. Ltd. Gumma Japan',
#  'CharlesWilliamMoss',
#  'MichaelThonet',
#  'IsamuKenmochi',
#  'JosephBurnett',
#  'DouglasSchwartz',
#  'interwareSARL',
#  'AnthonyIngolia',
#  'RobertoLucci PaoloOrlandini',
#  'RonSewell',
#  'GilbertA.Watrous',
#  'MarkoTurk',
#  'AlanSpigelman',
#  'SergeMouille',
#  'RichardHudson',
#  'JeanProuvé PierreMissey',
#  'RayKomai',
#  'FlorisMeydam',
#  'MorrisZerner',
#  'GioPonti',
#  'PeterSvannäs',
#  'SonyCorporation Tokyo',
#  'WillyKaufmann',
#  'HansTollin',
#  'GeorgeLadas',
#  'TakahamaKazuhide',
#  'OswaldHaerdtl',
#  'OwenF.Maclaren',
#  'ButchWalker',
#  'RobertoMatta',
#  'EugeneWalters',
#  'LibbeyGlassCompanyDivision OwensIllinoisCo. Toledo OH',
#  'TheodorPuschkarski',
#  'Lamson&Goodnow ShellbergFalls MA',
#  'EileenGray',
#  'FriedrichHerderA.G. Solingen Germany',
#  'PeterSciascin',
#  'IrwinGershen',
#  'AlfredKarlZlevor',
#  'LeopoldoMenegatti',
#  'GiuseppeCappelli',
#  'VanDayTruex',
#  'LuigiCacciaDominioni',
#  'EricRivkin RobertJ.Debrey KentMacintosh',
#  'RudolfMoethe',
#  'WolfgangvonWersin',
#  'WilhelmWagenfeld CarlJakobJucker',
#  'FratelliBrambilla Milan',
#  'RobinChu JackDaly ChristopherLoew',
#  "CompagniedeL'EsthétiqueIndustrielle(CEI)RaymondLoewy Paris DouglasKelley RogerRiche",
#  'JimGentes',
#  'GerdAlfredMüller RobertOberheim',
#  'SydneyCash',
#  'WalterGropius',
#  'ShigeyoshiMorioka',
#  'AndreasMoritz',
#  'OttoNatzler',
#  'HansH.Rath',
#  'DorothyRuddick',
#  'DarrellLandrum LouisJ.Zerbee',
#  'HapSakwa',
#  'RichardSchultz',
#  'FransvanNieuwenborg MartijnWegman',
#  'GeorgeNelson RonaldBeckman JohnSvezia RayWilkes IrvingHarper GeorgeNelsonAssociates',
#  'EugeneMartinez',
#  'KochCreations Lynbrook NY',
#  'MortN.Marton BerylMarton',
#  'DieterRams HochschulefürGestaltung Ulm Germany',
#  'DoloresDembusBittleman',
#  ...]

# %% [markdown]
# Looking to see if there are anymore names that need fixing

# %%
Artist_names = ['Artist_{0}'.format(c) for c in range(31)]
Artist_names
# Out:
# ['Artist_0',
#  'Artist_1',
#  'Artist_2',
#  'Artist_3',
#  'Artist_4',
#  'Artist_5',
#  'Artist_6',
#  'Artist_7',
#  'Artist_8',
#  'Artist_9',
#  'Artist_10',
#  'Artist_11',
#  'Artist_12',
#  'Artist_13',
#  'Artist_14',
#  'Artist_15',
#  'Artist_16',
#  'Artist_17',
#  'Artist_18',
#  'Artist_19',
#  'Artist_20',
#  'Artist_21',
#  'Artist_22',
#  'Artist_23',
#  'Artist_24',
#  'Artist_25',
#  'Artist_26',
#  'Artist_27',
#  'Artist_28',
#  'Artist_29',
#  'Artist_30']

# %% [markdown]
# Making 31 columns for the artists when they will be separated

# %%
artwork['ArtistStrip'] = artwork['ArtistStrip'].astype(str)

# %% [markdown]
# Converting the ArtistStrip from object to type string

# %%
(artwork
>>separate(X.ArtistStrip, Artist_names ,remove=False, convert=True,extra='drop', fill='right')
>>select(X.ArtistStrip,X.Artist_0,X.Artist_1,X.Artist_2))
# Out:
#                                               ArtistStrip  \
# 0                                              OttoWagner
# 1                                  ChristianDePortzamparc
# 2                                               EmilHoppe
# 3                                          BernardTschumi
# 4                                               EmilHoppe
# ...                                                   ...
# 138146  ChesnuttBrothersStudio AndrewChesnutt LewisChe...
# 138147                                   SophieTaeuberArp
# 138148                                   SophieTaeuberArp
# 138149                                   SophieTaeuberArp
# 138150                                   SophieTaeuberArp
#
#                       Artist_0        Artist_1       Artist_2
# 0                   OttoWagner             NaN            NaN
# 1       ChristianDePortzamparc             NaN            NaN
# 2                    EmilHoppe             NaN            NaN
# 3               BernardTschumi             NaN            NaN
# 4                    EmilHoppe             NaN            NaN
# ...                        ...             ...            ...
# 138146  ChesnuttBrothersStudio  AndrewChesnutt  LewisChesnutt
# 138147        SophieTaeuberArp             NaN            NaN
# 138148        SophieTaeuberArp             NaN            NaN
# 138149        SophieTaeuberArp             NaN            NaN
# 138150        SophieTaeuberArp             NaN            NaN
#
# [138151 rows x 4 columns]

# %%
artwork = (artwork
>>separate(X.ArtistStrip, Artist_names ,remove=False, convert=True,extra='drop', fill='right'))

# %% [markdown]
# Checked to see if the separate works first which is did then I saved the results into artwork

# %%
Artist_columns = contains('Artist_').evaluate(artwork)
Artist_columns
# Out:
# ['Artist_0',
#  'Artist_1',
#  'Artist_2',
#  'Artist_3',
#  'Artist_4',
#  'Artist_5',
#  'Artist_6',
#  'Artist_7',
#  'Artist_8',
#  'Artist_9',
#  'Artist_10',
#  'Artist_11',
#  'Artist_12',
#  'Artist_13',
#  'Artist_14',
#  'Artist_15',
#  'Artist_16',
#  'Artist_17',
#  'Artist_18',
#  'Artist_19',
#  'Artist_20',
#  'Artist_21',
#  'Artist_22',
#  'Artist_23',
#  'Artist_24',
#  'Artist_25',
#  'Artist_26',
#  'Artist_27',
#  'Artist_28',
#  'Artist_29',
#  'Artist_30']

# %% [markdown]
# Here I am grabbing the columns that start with Artist_ and then evaluating them on the data set

# %%
split_names = lambda string: re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', string)

# %%
artwork[Artist_columns] = artwork[Artist_columns].astype(str)

# %%
artist_names = {'{0}'.format(c):X[c].apply(split_names)
                  for c in Artist_columns}
artist_names
# Out:
# {'Artist_0': <dfply.base.Intention at 0x7f562a4d7c90>,
#  'Artist_1': <dfply.base.Intention at 0x7f560c8642d0>,
#  'Artist_2': <dfply.base.Intention at 0x7f560c864590>,
#  'Artist_3': <dfply.base.Intention at 0x7f560c864850>,
#  'Artist_4': <dfply.base.Intention at 0x7f560c864b10>,
#  'Artist_5': <dfply.base.Intention at 0x7f560c864dd0>,
#  'Artist_6': <dfply.base.Intention at 0x7f560c8650d0>,
#  'Artist_7': <dfply.base.Intention at 0x7f560c865390>,
#  'Artist_8': <dfply.base.Intention at 0x7f560c865650>,
#  'Artist_9': <dfply.base.Intention at 0x7f560c865910>,
#  'Artist_10': <dfply.base.Intention at 0x7f560c865bd0>,
#  'Artist_11': <dfply.base.Intention at 0x7f560c865e90>,
#  'Artist_12': <dfply.base.Intention at 0x7f560c868190>,
#  'Artist_13': <dfply.base.Intention at 0x7f560c868450>,
#  'Artist_14': <dfply.base.Intention at 0x7f560c868710>,
#  'Artist_15': <dfply.base.Intention at 0x7f560c8689d0>,
#  'Artist_16': <dfply.base.Intention at 0x7f560c868cd0>,
#  'Artist_17': <dfply.base.Intention at 0x7f560c86a050>,
#  'Artist_18': <dfply.base.Intention at 0x7f560c86a390>,
#  'Artist_19': <dfply.base.Intention at 0x7f560c86a6d0>,
#  'Artist_20': <dfply.base.Intention at 0x7f560c86aa10>,
#  'Artist_21': <dfply.base.Intention at 0x7f560c86ad50>,
#  'Artist_22': <dfply.base.Intention at 0x7f560c86b0d0>,
#  'Artist_23': <dfply.base.Intention at 0x7f560c86b410>,
#  'Artist_24': <dfply.base.Intention at 0x7f560c86b750>,
#  'Artist_25': <dfply.base.Intention at 0x7f560c86ba90>,
#  'Artist_26': <dfply.base.Intention at 0x7f560c86bdd0>,
#  'Artist_27': <dfply.base.Intention at 0x7f560c86d150>,
#  'Artist_28': <dfply.base.Intention at 0x7f560c86d490>,
#  'Artist_29': <dfply.base.Intention at 0x7f560c86d7d0>,
#  'Artist_30': <dfply.base.Intention at 0x7f5655f29b10>}

# %%
artwork = (artwork
>> mutate(**artist_names))

# %%
(artwork
>>select(X.ArtistStrip,X.Artist_0,X.Artist_1))
# Out:
#                                               ArtistStrip  \
# 0                                              OttoWagner
# 1                                  ChristianDePortzamparc
# 2                                               EmilHoppe
# 3                                          BernardTschumi
# 4                                               EmilHoppe
# ...                                                   ...
# 138146  ChesnuttBrothersStudio AndrewChesnutt LewisChe...
# 138147                                   SophieTaeuberArp
# 138148                                   SophieTaeuberArp
# 138149                                   SophieTaeuberArp
# 138150                                   SophieTaeuberArp
#
#                         Artist_0         Artist_1
# 0                    Otto Wagner              nan
# 1       Christian De Portzamparc              nan
# 2                     Emil Hoppe              nan
# 3                Bernard Tschumi              nan
# 4                     Emil Hoppe              nan
# ...                          ...              ...
# 138146  Chesnutt Brothers Studio  Andrew Chesnutt
# 138147        Sophie Taeuber Arp              nan
# 138148        Sophie Taeuber Arp              nan
# 138149        Sophie Taeuber Arp              nan
# 138150        Sophie Taeuber Arp              nan
#
# [138151 rows x 3 columns]

# %% [markdown]
# The code above makes a lambda that will replace the pattern of lowercase uppercase lettesr with spaces. So HeLlo -> He Llo. I unpacked the expression using the **artist_names. Then i selected couple of columns to see if it worked and it did split correctly

# %%
artwork = (artwork
>> mutate(Nationality_Stripped = X.Nationality.str.replace('[()]', ''))
)
artwork
# Out:
# /home/vn6415dw/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/dfply/base.py:82: FutureWarning: The default value of regex will change from True to False in a future version.
#   **_context_kwargs(kwargs)(x)),
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... Artist_22  \
# 0           Ink and cut-and-pasted painted pages on paper  ...       nan
# 1                       Paint and colored pencil on print  ...       nan
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...       nan
# 3       Photographic reproduction with colored synthet...  ...       nan
# 4       Graphite, color pencil, ink, and gouache on tr...  ...       nan
# ...                                                   ...  ...       ...
# 138146                               Gelatin silver print  ...       nan
# 138147  One from an illustrated book with four line bl...  ...       nan
# 138148  One from an illustrated book with four line bl...  ...       nan
# 138149  One from an illustrated book with four line bl...  ...       nan
# 138150  One from an illustrated book with four line bl...  ...       nan
#
#        Artist_23 Artist_24 Artist_25 Artist_26 Artist_27 Artist_28  Artist_29  \
# 0            nan       nan       nan       nan       nan       nan        nan
# 1            nan       nan       nan       nan       nan       nan        nan
# 2            nan       nan       nan       nan       nan       nan        nan
# 3            nan       nan       nan       nan       nan       nan        nan
# 4            nan       nan       nan       nan       nan       nan        nan
# ...          ...       ...       ...       ...       ...       ...        ...
# 138146       nan       nan       nan       nan       nan       nan        nan
# 138147       nan       nan       nan       nan       nan       nan        nan
# 138148       nan       nan       nan       nan       nan       nan        nan
# 138149       nan       nan       nan       nan       nan       nan        nan
# 138150       nan       nan       nan       nan       nan       nan        nan
#
#        Artist_30 Nationality_Stripped
# 0            nan             Austrian
# 1            nan               French
# 2            nan             Austrian
# 3            nan
# 4            nan             Austrian
# ...          ...                  ...
# 138146       nan    American American
# 138147       nan                Swiss
# 138148       nan                Swiss
# 138149       nan                Swiss
# 138150       nan                Swiss
#
# [138151 rows x 158 columns]

# %%
artwork.Nationality_Stripped.value_counts()
# Out:
# American                                     56963
# French                                       22589
# German                                        9239
# British                                       5576
#                                               5025
#                                              ...
# French French Romanian American Romanian         1
# American Russian German American American        1
# American    Italian                              1
# French British Portuguese French German          1
# Russian Russian                                  1
# Name: Nationality_Stripped, Length: 1053, dtype: int64

# %%
nat_names = ['Nationality_{0}'.format(c) for c in range(31)]
nat_names
# Out:
# ['Nationality_0',
#  'Nationality_1',
#  'Nationality_2',
#  'Nationality_3',
#  'Nationality_4',
#  'Nationality_5',
#  'Nationality_6',
#  'Nationality_7',
#  'Nationality_8',
#  'Nationality_9',
#  'Nationality_10',
#  'Nationality_11',
#  'Nationality_12',
#  'Nationality_13',
#  'Nationality_14',
#  'Nationality_15',
#  'Nationality_16',
#  'Nationality_17',
#  'Nationality_18',
#  'Nationality_19',
#  'Nationality_20',
#  'Nationality_21',
#  'Nationality_22',
#  'Nationality_23',
#  'Nationality_24',
#  'Nationality_25',
#  'Nationality_26',
#  'Nationality_27',
#  'Nationality_28',
#  'Nationality_29',
#  'Nationality_30']

# %%
artwork['Nationality_Stripped'] = artwork['Nationality_Stripped'].astype(str)

# %%
(artwork
>>separate(X.Nationality_Stripped, nat_names ,remove=False, convert=True,extra='drop', fill='right')
>>select(X.Nationality_Stripped,X.Nationality_0,X.Nationality_1,X.Nationality_2))
# Out:
#        Nationality_Stripped Nationality_0 Nationality_1 Nationality_2
# 0                  Austrian      Austrian           NaN           NaN
# 1                    French        French           NaN           NaN
# 2                  Austrian      Austrian           NaN           NaN
# 3                                     NaN           NaN           NaN
# 4                  Austrian      Austrian           NaN           NaN
# ...                     ...           ...           ...           ...
# 138146    American American           NaN      American      American
# 138147                Swiss         Swiss           NaN           NaN
# 138148                Swiss         Swiss           NaN           NaN
# 138149                Swiss         Swiss           NaN           NaN
# 138150                Swiss         Swiss           NaN           NaN
#
# [138151 rows x 4 columns]

# %%
artwork = (artwork
>>separate(X.Nationality_Stripped, nat_names ,remove=False, convert=True,extra='drop', fill='right'))
artwork
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                (0)
# 2                     (Austrian)             (1876)             (1957)
# 3                             ()             (1944)                (0)
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  ... Nationality_21  \
# 0           Ink and cut-and-pasted painted pages on paper  ...            NaN
# 1                       Paint and colored pencil on print  ...            NaN
# 2       Graphite, pen, color pencil, ink, and gouache ...  ...            NaN
# 3       Photographic reproduction with colored synthet...  ...            NaN
# 4       Graphite, color pencil, ink, and gouache on tr...  ...            NaN
# ...                                                   ...  ...            ...
# 138146                               Gelatin silver print  ...            NaN
# 138147  One from an illustrated book with four line bl...  ...            NaN
# 138148  One from an illustrated book with four line bl...  ...            NaN
# 138149  One from an illustrated book with four line bl...  ...            NaN
# 138150  One from an illustrated book with four line bl...  ...            NaN
#
#        Nationality_22 Nationality_23 Nationality_24 Nationality_25  \
# 0                 NaN            NaN            NaN            NaN
# 1                 NaN            NaN            NaN            NaN
# 2                 NaN            NaN            NaN            NaN
# 3                 NaN            NaN            NaN            NaN
# 4                 NaN            NaN            NaN            NaN
# ...               ...            ...            ...            ...
# 138146            NaN            NaN            NaN            NaN
# 138147            NaN            NaN            NaN            NaN
# 138148            NaN            NaN            NaN            NaN
# 138149            NaN            NaN            NaN            NaN
# 138150            NaN            NaN            NaN            NaN
#
#        Nationality_26 Nationality_27  Nationality_28 Nationality_29  \
# 0                 NaN            NaN             NaN            NaN
# 1                 NaN            NaN             NaN            NaN
# 2                 NaN            NaN             NaN            NaN
# 3                 NaN            NaN             NaN            NaN
# 4                 NaN            NaN             NaN            NaN
# ...               ...            ...             ...            ...
# 138146            NaN            NaN             NaN            NaN
# 138147            NaN            NaN             NaN            NaN
# 138148            NaN            NaN             NaN            NaN
# 138149            NaN            NaN             NaN            NaN
# 138150            NaN            NaN             NaN            NaN
#
#        Nationality_30
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 138146            NaN
# 138147            NaN
# 138148            NaN
# 138149            NaN
# 138150            NaN
#
# [138151 rows x 189 columns]

# %% [markdown]
# For the code for nationality I looked at value_counts() to help show what values there are and how many it occurs. Next I made my 31 columns and applied the separate function on the Nationality stripped column (called stripped because the () were replaced or got rid of). I selected a couple of columns to make sure it split correctly then saved it into artwork

# %%
Begin_columns = contains('BeginDate_').evaluate(artwork)
Begin_columns
# Out:
# ['BeginDate_strip',
#  'BeginDate_0',
#  'BeginDate_1',
#  'BeginDate_2',
#  'BeginDate_3',
#  'BeginDate_4',
#  'BeginDate_5',
#  'BeginDate_6',
#  'BeginDate_7',
#  'BeginDate_8',
#  'BeginDate_9',
#  'BeginDate_10',
#  'BeginDate_11',
#  'BeginDate_12',
#  'BeginDate_13',
#  'BeginDate_14',
#  'BeginDate_15',
#  'BeginDate_16',
#  'BeginDate_17',
#  'BeginDate_18',
#  'BeginDate_19',
#  'BeginDate_20',
#  'BeginDate_21',
#  'BeginDate_22',
#  'BeginDate_23',
#  'BeginDate_24',
#  'BeginDate_25',
#  'BeginDate_26',
#  'BeginDate_27',
#  'BeginDate_28',
#  'BeginDate_29',
#  'BeginDate_30']

# %%
End_columns = contains('EndDate_').evaluate(artwork)
End_columns
# Out:
# ['EndDate_strip',
#  'EndDate_0',
#  'EndDate_1',
#  'EndDate_2',
#  'EndDate_3',
#  'EndDate_4',
#  'EndDate_5',
#  'EndDate_6',
#  'EndDate_7',
#  'EndDate_8',
#  'EndDate_9',
#  'EndDate_10',
#  'EndDate_11',
#  'EndDate_12',
#  'EndDate_13',
#  'EndDate_14',
#  'EndDate_15',
#  'EndDate_16',
#  'EndDate_17',
#  'EndDate_18',
#  'EndDate_19',
#  'EndDate_20',
#  'EndDate_21',
#  'EndDate_22',
#  'EndDate_23',
#  'EndDate_24',
#  'EndDate_25',
#  'EndDate_26',
#  'EndDate_27',
#  'EndDate_28',
#  'EndDate_29',
#  'EndDate_30']

# %%
Begin_columns = Begin_columns[1:]
End_columns = End_columns[1:]

# %%
pd.to_numeric(artwork.BeginDate_0, errors = 'coerce')
# Out:
# 0         1841.0
# 1         1944.0
# 2         1876.0
# 3         1944.0
# 4         1876.0
#            ...
# 138146       0.0
# 138147    1889.0
# 138148    1889.0
# 138149    1889.0
# 138150    1889.0
# Name: BeginDate_0, Length: 138151, dtype: float64

# %%
artwork[Begin_columns] = artwork[Begin_columns].apply(pd.to_numeric, errors = 'coerce')

# %%
artwork.BeginDate_0.dtype
# Out:
# dtype('float64')

# %%
artwork[End_columns] = artwork[End_columns].apply(pd.to_numeric, errors = 'coerce')

# %%
artwork.EndDate_0.dtype
# Out:
# dtype('float64')

# %%
list(artwork.columns)
# Out:
# ['Title',
#  'Artist',
#  'ConstituentID',
#  'ArtistBio',
#  'Nationality',
#  'BeginDate',
#  'EndDate',
#  'Gender',
#  'Date',
#  'Medium',
#  'Dimensions',
#  'CreditLine',
#  'AccessionNumber',
#  'Classification',
#  'Department',
#  'DateAcquired',
#  'Cataloged',
#  'ObjectID',
#  'URL',
#  'ThumbnailURL',
#  'Circumference_cm',
#  'Depth_cm',
#  'Diameter_cm',
#  'Height_cm',
#  'Length_cm',
#  'Weight_kg',
#  'Width_cm',
#  'Seat_Height_cm',
#  'Duration_sec',
#  'EndDate_strip',
#  'Gender_Stripped',
#  'Gender_0',
#  'Gender_1',
#  'Gender_2',
#  'Gender_3',
#  'Gender_4',
#  'Gender_5',
#  'Gender_6',
#  'Gender_7',
#  'Gender_8',
#  'Gender_9',
#  'Gender_10',
#  'Gender_11',
#  'Gender_12',
#  'Gender_13',
#  'Gender_14',
#  'Gender_15',
#  'Gender_16',
#  'Gender_17',
#  'Gender_18',
#  'Gender_19',
#  'Gender_20',
#  'Gender_21',
#  'Gender_22',
#  'Gender_23',
#  'Gender_24',
#  'Gender_25',
#  'Gender_26',
#  'Gender_27',
#  'Gender_28',
#  'Gender_29',
#  'Gender_30',
#  'BeginDate_strip',
#  'BeginDate_0',
#  'BeginDate_1',
#  'BeginDate_2',
#  'BeginDate_3',
#  'BeginDate_4',
#  'BeginDate_5',
#  'BeginDate_6',
#  'BeginDate_7',
#  'BeginDate_8',
#  'BeginDate_9',
#  'BeginDate_10',
#  'BeginDate_11',
#  'BeginDate_12',
#  'BeginDate_13',
#  'BeginDate_14',
#  'BeginDate_15',
#  'BeginDate_16',
#  'BeginDate_17',
#  'BeginDate_18',
#  'BeginDate_19',
#  'BeginDate_20',
#  'BeginDate_21',
#  'BeginDate_22',
#  'BeginDate_23',
#  'BeginDate_24',
#  'BeginDate_25',
#  'BeginDate_26',
#  'BeginDate_27',
#  'BeginDate_28',
#  'BeginDate_29',
#  'BeginDate_30',
#  'EndDate_0',
#  'EndDate_1',
#  'EndDate_2',
#  'EndDate_3',
#  'EndDate_4',
#  'EndDate_5',
#  'EndDate_6',
#  'EndDate_7',
#  'EndDate_8',
#  'EndDate_9',
#  'EndDate_10',
#  'EndDate_11',
#  'EndDate_12',
#  'EndDate_13',
#  'EndDate_14',
#  'EndDate_15',
#  'EndDate_16',
#  'EndDate_17',
#  'EndDate_18',
#  'EndDate_19',
#  'EndDate_20',
#  'EndDate_21',
#  'EndDate_22',
#  'EndDate_23',
#  'EndDate_24',
#  'EndDate_25',
#  'EndDate_26',
#  'EndDate_27',
#  'EndDate_28',
#  'EndDate_29',
#  'EndDate_30',
#  'ArtistStrip',
#  'Artist_0',
#  'Artist_1',
#  'Artist_2',
#  'Artist_3',
#  'Artist_4',
#  'Artist_5',
#  'Artist_6',
#  'Artist_7',
#  'Artist_8',
#  'Artist_9',
#  'Artist_10',
#  'Artist_11',
#  'Artist_12',
#  'Artist_13',
#  'Artist_14',
#  'Artist_15',
#  'Artist_16',
#  'Artist_17',
#  'Artist_18',
#  'Artist_19',
#  'Artist_20',
#  'Artist_21',
#  'Artist_22',
#  'Artist_23',
#  'Artist_24',
#  'Artist_25',
#  'Artist_26',
#  'Artist_27',
#  'Artist_28',
#  'Artist_29',
#  'Artist_30',
#  'Nationality_Stripped',
#  'Nationality_0',
#  'Nationality_1',
#  'Nationality_2',
#  'Nationality_3',
#  'Nationality_4',
#  'Nationality_5',
#  'Nationality_6',
#  'Nationality_7',
#  'Nationality_8',
#  'Nationality_9',
#  'Nationality_10',
#  'Nationality_11',
#  'Nationality_12',
#  'Nationality_13',
#  'Nationality_14',
#  'Nationality_15',
#  'Nationality_16',
#  'Nationality_17',
#  'Nationality_18',
#  'Nationality_19',
#  'Nationality_20',
#  'Nationality_21',
#  'Nationality_22',
#  'Nationality_23',
#  'Nationality_24',
#  'Nationality_25',
#  'Nationality_26',
#  'Nationality_27',
#  'Nationality_28',
#  'Nationality_29',
#  'Nationality_30']
